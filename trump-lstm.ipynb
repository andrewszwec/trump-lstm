# %% [markdown]
# # Trump Tweet Generation
#
#
# ## Get the Data
# The data is already provided for you.  You'll be using a subset of the original dataset.  It consists of only the scenes in Moe's Tavern.  This doesn't include other versions of the tavern, like "Moe's Cavern", "Flaming Moe's", "Uncle Moe's Family Feed-Bag", etc..

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

data_dir = './data/trump-tweets.txt'
text = helper.load_data(data_dir)
# Ignore notice, since we don't use it for analysing the data
#text = text[81:]

# %% [markdown]
# ## Explore the Data
# Play around with `view_sentence_range` to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in text.split()})))
scenes = text.split('\n\n')

sentences = [sentence for scene in scenes for sentence in scene.split('\n')]
print('Number of lines: {}'.format(len(sentences)))
word_count_sentence = [len(sentence.split()) for sentence in sentences]
print('Average number of words in each line: {}'.format(np.average(word_count_sentence)))

print()
print('The sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 82467
# Number of lines: 33614
# Average number of words in each line: 15.468971261974177
#
# The sentences 0 to 10:
# "RT @FLOTUS: I had a wonderful time with the students at the American International School #Riyadh today. #SaudiaArabia https://t.co/AVzVV0W…"
# "Thank you to the BRAVE servicemen &amp; women who have served, and continue to serve the United States- our true HEROES! #ArmedForcesDay https://t.co/5Kkh0PYs5A"
# "Great to be in Riyadh, Saudi Arabia. Looking forward to the afternoon and evening ahead. #POTUSAbroad https://t.co/JJOra0KfyR"
# "#WeeklyAddress🇺🇸
# ➡️https://t.co/UYEhgch4Hl https://t.co/HIQoFuc5cy"
# "Getting ready for my big foreign trip. Will be strongly protecting American interests - that's what I like to do!"
# "\"President Donald J. Trump Proclaims 5/14/2017 through 5/20/2017 as #PoliceWeek\"
# Proclamation➡️https://t.co/oS8IfHz3xA
# #ThankACop #LESM https://t.co/r5n8EfMCI0"
# "A great honor to welcome President Juan Manuel Santos of Colombia to the White House today!🇺🇸🇨🇴

# %% [markdown]
# ## Implement Preprocessing Functions
# The first thing to do to any dataset is preprocessing.  Implement the following preprocessing functions below:
# - Lookup Table
# - Tokenize Punctuation
#
# ### Lookup Table
# To create a word embedding, you first need to transform the words to ids.  In this function, create two dictionaries:
# - Dictionary to go from the words to an id, we'll call `vocab_to_int`
# - Dictionary to go from the id to word, we'll call `int_to_vocab`
#
# Return these dictionaries in the following tuple `(vocab_to_int, int_to_vocab)`

# %%
import numpy as np
import problem_unittests as tests
import tensorflow as tf

def create_lookup_tables(text):
    """
    Create lookup tables for vocabulary
    :param text: The text of tv scripts split into words
    :return: A tuple of dicts (vocab_to_int, int_to_vocab)
    """
    # TODO: Implement Function
    vocab = set(text)
    vocab_to_int = {c: i for i, c in enumerate(vocab)}
    int_to_vocab = dict(enumerate(vocab))

    return vocab_to_int, int_to_vocab

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_create_lookup_tables(create_lookup_tables)
# Out:
# Tests Passed

# %% [markdown]
# ### Tokenize Punctuation
# We'll be splitting the script into a word array using spaces as delimiters.  However, punctuations like periods and exclamation marks make it hard for the neural network to distinguish between the word "bye" and "bye!".
#
# Implement the function `token_lookup` to return a dict that will be used to tokenize symbols like "!" into "||Exclamation_Mark||".  Create a dictionary for the following symbols where the symbol is the key and value is the token:
# - Period ( . )
# - Comma ( , )
# - Quotation Mark ( " )
# - Semicolon ( ; )
# - Exclamation mark ( ! )
# - Question mark ( ? )
# - Left Parentheses ( ( )
# - Right Parentheses ( ) )
# - Dash ( -- )
# - Return ( \n )
#
# This dictionary will be used to token the symbols and add the delimiter (space) around it.  This separates the symbols as it's own word, making it easier for the neural network to predict on the next word. Make sure you don't use a token that could be confused as a word. Instead of using the token "dash", try using something like "||dash||".

# %%
def token_lookup():
    """
    Generate a dict to turn punctuation into a token.
    :return: Tokenize dictionary where the key is the punctuation and the value is the token
    """
    # TODO: Implement Function
    lookup = {'.' : '||Period||'
               ,   ','  : '||Comma||'
               , '"' : '||Quotation-Mark||'
               , ';' : '||Semicolon||'
               , '!' : '||Exclamation-mark||'
               , '?' : '||Question-mark||'
               , '(' : '||Left-Parentheses||'
               , ')' : '||Right-Parentheses||'
               , '--' : '||Double-Dash||'
               , '-' : '||Dash||'
               , '\n' : '||Return||'
               , '@' : '||At||'
               , '#' : '||Hash||'
               , '/' : '||Forwad-Slash||'
               , '\\' : '||Back-Slash||'
             }
    return lookup

print('Done')
# Out:
# Done

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(data_dir, token_lookup, create_lookup_tables)
print('Done')
# Out:
# Done

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import numpy as np
import problem_unittests as tests

int_text, vocab_to_int, int_to_vocab, token_dict = helper.load_preprocess()

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a RNN by implementing the following functions below:
# - get_inputs
# - get_init_cell
# - get_embed
# - build_rnn
# - build_nn
# - get_batches
#
# ### Check the Version of TensorFlow and Access to GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `get_inputs()` function to create TF Placeholders for the Neural Network.  It should create the following placeholders:
# - Input text placeholder named "input" using the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) `name` parameter.
# - Targets placeholder
# - Learning Rate placeholder
#
# Return the placeholders in the following the tuple `(Input, Targets, LearingRate)`

# %%
def get_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate)
    """
    # TODO: Implement Function
    #mySize = len(vocab_to_int)
    Input = tf.placeholder(tf.int32, [None, None], name='input')
    Targets = tf.placeholder(tf.int32, [None, None], name='target')
    LearingRate = tf.placeholder(tf.float32, name='learning_rate')
    
    return Input, Targets, LearingRate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_get_inputs(get_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Build RNN Cell and Initialize
# Stack one or more [`BasicLSTMCells`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/BasicLSTMCell) in a [`MultiRNNCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/MultiRNNCell).
# - The Rnn size should be set using `rnn_size`
# - Initalize Cell State using the MultiRNNCell's [`zero_state()`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/MultiRNNCell#zero_state) function
#     - Apply the name "initial_state" to the initial state using [`tf.identity()`](https://www.tensorflow.org/api_docs/python/tf/identity)
#
# Return the cell and initial state in the following tuple `(Cell, InitialState)`

# %%
def get_init_cell(batch_size, rnn_size):
    """
    Create an RNN Cell and initialize it.
    :param batch_size: Size of batches
    :param rnn_size: Size of RNNs
    :return: Tuple (cell, initialize state)
    """
    # TODO: Implement Function
    num_layers = 2
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    keep_prob = 0.5
    
    ### Build the RNN layers
    # Use a basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    
    # Add dropout to the cell
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    #drop = lstm    
    
    # Stack up 2 LSTM layers, for "deep learning"
    cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    initial_state = tf.identity(cell.zero_state(batch_size, tf.float32), name='initial_state')        
        
    return cell, initial_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_get_init_cell(get_init_cell)
# Out:
# Tests Passed

# %% [markdown]
# ### Word Embedding
# Apply embedding to `input_data` using TensorFlow.  Return the embedded sequence.

# %%
def get_embed(input_data, vocab_size, embed_dim):
    
    """
    Create embedding for <input_data>.
    :param input_data: TF placeholder for text input.
    :param vocab_size: Number of words in vocabulary.
    :param embed_dim: Number of embedding dimensions
    :return: Embedded input.
    """
    # TODO: Implement Function
    # Alternative
    #embedding = tf.Variable( tf.random_uniform([vocab_size, embed_dim], -1.0, 1.0)) 
    embedding = tf.Variable(tf.truncated_normal([vocab_size, embed_dim], mean=0.0, stddev=1.0)) 
    embed = tf.nn.embedding_lookup(embedding, input_data)
    
    # Alternative
    #embed = tf.contrib.layers.embed_sequence(embedding, input_data)
    return embed
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_get_embed(get_embed)
# Out:
# Tests Passed

# %% [markdown]
# ### Build RNN
# You created a RNN Cell in the `get_init_cell()` function.  Time to use the cell to create a RNN.
# - Build the RNN using the [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)
#  - Apply the name "final_state" to the final state using [`tf.identity()`](https://www.tensorflow.org/api_docs/python/tf/identity)
#
# Return the outputs and final_state state in the following tuple `(Outputs, FinalState)`

# %%
def build_rnn(cell, inputs):
    """
    Create a RNN using a RNN Cell
    :param cell: RNN Cell
    :param inputs: Input text data
    :return: Tuple (Outputs, Final State)
    """
    # TODO: Implement Function
      
    outputs, state = tf.nn.dynamic_rnn(cell, inputs, dtype=tf.float32)
    final_state = tf.identity(state, name="final_state")  
    
    return outputs, final_state


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_build_rnn(build_rnn)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
# - Apply embedding to `input_data` using your `get_embed(input_data, vocab_size, embed_dim)` function.
# - Build RNN using `cell` and your `build_rnn(cell, inputs)` function.
# - Apply a fully connected layer with a linear activation and `vocab_size` as the number of outputs.
#
# Return the logits and final state in the following tuple (Logits, FinalState)

# %%
def build_nn(cell, rnn_size, input_data, vocab_size):
    """
    Build part of the neural network
    :param cell: RNN cell
    :param rnn_size: Size of rnns
    :param input_data: Input data
    :param vocab_size: Vocabulary size
    :return: Tuple (Logits, FinalState)
    """
    # TODO: Implement Function
    embed_dim = 256
    
    embed = get_embed(input_data, vocab_size, embed_dim)
    output, final_state = build_rnn(cell, embed)
    
    logits = tf.layers.dense(output, 
                             vocab_size, 
                             kernel_initializer=tf.truncated_normal_initializer(stddev=0.1), 
                             bias_initializer=tf.zeros_initializer(), 
                             activation = None)
    
    return logits, final_state
      
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_build_nn(build_nn)
# Out:
# Tests Passed

# %%
# TODO: Implement Function
def get_batches(int_text, batch_size, seq_length):
    n_batches = len(int_text) // (batch_size*seq_length)

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return np.asarray(list(zip(x_batches, y_batches)))
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_get_batches(get_batches)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `num_epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `seq_length` to the length of sequence.
# - Set `learning_rate` to the learning rate.
# - Set `show_every_n_batches` to the number of batches the neural network should print progress.

# %%
# Number of Epochs
num_epochs = 100
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 256
# Sequence Length
seq_length = 15 # average length of sentence is ~15 words
# Learning Rate
learning_rate = 0.01  # tried 0.1, but the result were not good
# Show stats for every n number of batches
show_every_n_batches = 10

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
save_dir = './save'

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from tensorflow.contrib import seq2seq

train_graph = tf.Graph()
with train_graph.as_default():
    vocab_size = len(int_to_vocab)
    input_text, targets, lr = get_inputs()
    input_data_shape = tf.shape(input_text)
    cell, initial_state = get_init_cell(input_data_shape[0], rnn_size)
    logits, final_state = build_nn(cell, rnn_size, input_text, vocab_size)

    # Probabilities for generating words
    probs = tf.nn.softmax(logits, name='probs')

    # Loss function
    cost = seq2seq.sequence_loss(
        logits,
        targets,
        tf.ones([input_data_shape[0], input_data_shape[1]]))

    # Optimizer
    optimizer = tf.train.AdamOptimizer(lr)

    # Gradient Clipping
    gradients = optimizer.compute_gradients(cost)
    capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients]
    train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ## Train
# Train the neural network on the preprocessed data.  If you have a hard time getting a good loss, check the [forms](https://discussions.udacity.com/) to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
batches = get_batches(int_text, batch_size, seq_length)

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(num_epochs):
        state = sess.run(initial_state, {input_text: batches[0][0]})

        for batch_i, (x, y) in enumerate(batches):
            feed = {
                input_text: x,
                targets: y,
                initial_state: state,
                lr: learning_rate}
            train_loss, state, _ = sess.run([cost, final_state, train_op], feed)

            # Show every <show_every_n_batches> batches
            if (epoch_i * len(batches) + batch_i) % show_every_n_batches == 0:
                print('Epoch {:>3} Batch {:>4}/{}   train_loss = {:.3f}'.format(
                    epoch_i,
                    batch_i,
                    len(batches),
                    train_loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_dir)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/197   train_loss = 10.805
# Epoch   0 Batch   10/197   train_loss = 6.763
# Epoch   0 Batch   20/197   train_loss = 6.208
# Epoch   0 Batch   30/197   train_loss = 6.106
# Epoch   0 Batch   40/197   train_loss = 5.967
# Epoch   0 Batch   50/197   train_loss = 5.873
# Epoch   0 Batch   60/197   train_loss = 5.730
# Epoch   0 Batch   70/197   train_loss = 5.694
# Epoch   0 Batch   80/197   train_loss = 5.804
# Epoch   0 Batch   90/197   train_loss = 5.512
# Epoch   0 Batch  100/197   train_loss = 5.644
# Epoch   0 Batch  110/197   train_loss = 5.569
# Epoch   0 Batch  120/197   train_loss = 5.550
# Epoch   0 Batch  130/197   train_loss = 5.510
# Epoch   0 Batch  140/197   train_loss = 5.441
# Epoch   0 Batch  150/197   train_loss = 5.385
# Epoch   0 Batch  160/197   train_loss = 5.427
# Epoch   0 Batch  170/197   train_loss = 5.216
# Epoch   0 Batch  180/197   train_loss = 5.249
# Epoch   0 Batch  190/197   train_loss = 5.303
# Epoch   1 Batch    3/197   train_loss = 5.301
# Epoch   1 Batch   13/197   train_loss = 5.311
# Epoch   1 Batch   23/197   train_loss = 5.182
# Epoch   1 Batch   33/197   train_loss = 5.086
# Epoch   1 Batch   43/197   train_loss = 5.172
# Epoch   1 Batch   53/197   train_loss = 5.180
# Epoch   1 Batch   63/197   train_loss = 5.116
# Epoch   1 Batch   73/197   train_loss = 4.948
# Epoch   1 Batch   83/197   train_loss = 5.172
# Epoch   1 Batch   93/197   train_loss = 5.130
# Epoch   1 Batch  103/197   train_loss = 5.041
# Epoch   1 Batch  113/197   train_loss = 5.004
# Epoch   1 Batch  123/197   train_loss = 5.043
# Epoch   1 Batch  133/197   train_loss = 5.026
# Epoch   1 Batch  143/197   train_loss = 5.086
# Epoch   1 Batch  153/197   train_loss = 5.139
# Epoch   1 Batch  163/197   train_loss = 5.134
# Epoch   1 Batch  173/197   train_loss = 4.877
# Epoch   1 Batch  183/197   train_loss = 4.900
# Epoch   1 Batch  193/197   train_loss = 4.916
# Epoch   2 Batch    6/197   train_loss = 4.871
# Epoch   2 Batch   16/197   train_loss = 4.875
# Epoch   2 Batch   26/197   train_loss = 4.857
# Epoch   2 Batch   36/197   train_loss = 4.919
# Epoch   2 Batch   46/197   train_loss = 4.798
# Epoch   2 Batch   56/197   train_loss = 4.742
# Epoch   2 Batch   66/197   train_loss = 4.877
# Epoch   2 Batch   76/197   train_loss = 4.919
# Epoch   2 Batch   86/197   train_loss = 4.833
# Epoch   2 Batch   96/197   train_loss = 4.871
# Epoch   2 Batch  106/197   train_loss = 4.890
# Epoch   2 Batch  116/197   train_loss = 4.830
# Epoch   2 Batch  126/197   train_loss = 4.800
# Epoch   2 Batch  136/197   train_loss = 4.811
# Epoch   2 Batch  146/197   train_loss = 4.783
# Epoch   2 Batch  156/197   train_loss = 4.827
# Epoch   2 Batch  166/197   train_loss = 4.842
# Epoch   2 Batch  176/197   train_loss = 4.793
# Epoch   2 Batch  186/197   train_loss = 4.781
# Epoch   2 Batch  196/197   train_loss = 4.811
# Epoch   3 Batch    9/197   train_loss = 4.737
# Epoch   3 Batch   19/197   train_loss = 4.704
# Epoch   3 Batch   29/197   train_loss = 4.672
# Epoch   3 Batch   39/197   train_loss = 4.778
# Epoch   3 Batch   49/197   train_loss = 4.665
# Epoch   3 Batch   59/197   train_loss = 4.758
# Epoch   3 Batch   69/197   train_loss = 4.735
# Epoch   3 Batch   79/197   train_loss = 4.560
# Epoch   3 Batch   89/197   train_loss = 4.638
# Epoch   3 Batch   99/197   train_loss = 4.678
# Epoch   3 Batch  109/197   train_loss = 4.779
# Epoch   3 Batch  119/197   train_loss = 4.531
# Epoch   3 Batch  129/197   train_loss = 4.692
# Epoch   3 Batch  139/197   train_loss = 4.569
# Epoch   3 Batch  149/197   train_loss = 4.542
# Epoch   3 Batch  159/197   train_loss = 4.587
# Epoch   3 Batch  169/197   train_loss = 4.497
# Epoch   3 Batch  179/197   train_loss = 4.598
# Epoch   3 Batch  189/197   train_loss = 4.540
# Epoch   4 Batch    2/197   train_loss = 4.569
# Epoch   4 Batch   12/197   train_loss = 4.605
# Epoch   4 Batch   22/197   train_loss = 4.626
# Epoch   4 Batch   32/197   train_loss = 4.492
# Epoch   4 Batch   42/197   train_loss = 4.594
# Epoch   4 Batch   52/197   train_loss = 4.594
# Epoch   4 Batch   62/197   train_loss = 4.619
# Epoch   4 Batch   72/197   train_loss = 4.538
# Epoch   4 Batch   82/197   train_loss = 4.586
# Epoch   4 Batch   92/197   train_loss = 4.592
# Epoch   4 Batch  102/197   train_loss = 4.594
# Epoch   4 Batch  112/197   train_loss = 4.451
# Epoch   4 Batch  122/197   train_loss = 4.450
# Epoch   4 Batch  132/197   train_loss = 4.586
# Epoch   4 Batch  142/197   train_loss = 4.521
# Epoch   4 Batch  152/197   train_loss = 4.574
# Epoch   4 Batch  162/197   train_loss = 4.523
# Epoch   4 Batch  172/197   train_loss = 4.622
# Epoch   4 Batch  182/197   train_loss = 4.507
# Epoch   4 Batch  192/197   train_loss = 4.540
# Epoch   5 Batch    5/197   train_loss = 4.539
# Epoch   5 Batch   15/197   train_loss = 4.443
# Epoch   5 Batch   25/197   train_loss = 4.479
# Epoch   5 Batch   35/197   train_loss = 4.480
# Epoch   5 Batch   45/197   train_loss = 4.405
# Epoch   5 Batch   55/197   train_loss = 4.479
# Epoch   5 Batch   65/197   train_loss = 4.516
# Epoch   5 Batch   75/197   train_loss = 4.429
# Epoch   5 Batch   85/197   train_loss = 4.450
# Epoch   5 Batch   95/197   train_loss = 4.479
# Epoch   5 Batch  105/197   train_loss = 4.424
# Epoch   5 Batch  115/197   train_loss = 4.503
# Epoch   5 Batch  125/197   train_loss = 4.574
# Epoch   5 Batch  135/197   train_loss = 4.498
# Epoch   5 Batch  145/197   train_loss = 4.471
# Epoch   5 Batch  155/197   train_loss = 4.487
# Epoch   5 Batch  165/197   train_loss = 4.548
# Epoch   5 Batch  175/197   train_loss = 4.430
# Epoch   5 Batch  185/197   train_loss = 4.468
# Epoch   5 Batch  195/197   train_loss = 4.401
# Epoch   6 Batch    8/197   train_loss = 4.482
# Epoch   6 Batch   18/197   train_loss = 4.502
# Epoch   6 Batch   28/197   train_loss = 4.373
# Epoch   6 Batch   38/197   train_loss = 4.399
# Epoch   6 Batch   48/197   train_loss = 4.435
# Epoch   6 Batch   58/197   train_loss = 4.306
# Epoch   6 Batch   68/197   train_loss = 4.434
# Epoch   6 Batch   78/197   train_loss = 4.384
# Epoch   6 Batch   88/197   train_loss = 4.323
# Epoch   6 Batch   98/197   train_loss = 4.302
# Epoch   6 Batch  108/197   train_loss = 4.466
# Epoch   6 Batch  118/197   train_loss = 4.377
# Epoch   6 Batch  128/197   train_loss = 4.274
# Epoch   6 Batch  138/197   train_loss = 4.404
# Epoch   6 Batch  148/197   train_loss = 4.297
# Epoch   6 Batch  158/197   train_loss = 4.417
# Epoch   6 Batch  168/197   train_loss = 4.317
# Epoch   6 Batch  178/197   train_loss = 4.303
# Epoch   6 Batch  188/197   train_loss = 4.419
# Epoch   7 Batch    1/197   train_loss = 4.334
# Epoch   7 Batch   11/197   train_loss = 4.262
# Epoch   7 Batch   21/197   train_loss = 4.282
# Epoch   7 Batch   31/197   train_loss = 4.375
# Epoch   7 Batch   41/197   train_loss = 4.208
# Epoch   7 Batch   51/197   train_loss = 4.391
# Epoch   7 Batch   61/197   train_loss = 4.365
# Epoch   7 Batch   71/197   train_loss = 4.273
# Epoch   7 Batch   81/197   train_loss = 4.346
# Epoch   7 Batch   91/197   train_loss = 4.362
# Epoch   7 Batch  101/197   train_loss = 4.258
# Epoch   7 Batch  111/197   train_loss = 4.306
# Epoch   7 Batch  121/197   train_loss = 4.300
# Epoch   7 Batch  131/197   train_loss = 4.323
# Epoch   7 Batch  141/197   train_loss = 4.252
# Epoch   7 Batch  151/197   train_loss = 4.274
# Epoch   7 Batch  161/197   train_loss = 4.338
# Epoch   7 Batch  171/197   train_loss = 4.297
# Epoch   7 Batch  181/197   train_loss = 4.292
# Epoch   7 Batch  191/197   train_loss = 4.215
# Epoch   8 Batch    4/197   train_loss = 4.350
# Epoch   8 Batch   14/197   train_loss = 4.290
# Epoch   8 Batch   24/197   train_loss = 4.144
# Epoch   8 Batch   34/197   train_loss = 4.266
# Epoch   8 Batch   44/197   train_loss = 4.410
# Epoch   8 Batch   54/197   train_loss = 4.290
# Epoch   8 Batch   64/197   train_loss = 4.292
# Epoch   8 Batch   74/197   train_loss = 4.309
# Epoch   8 Batch   84/197   train_loss = 4.227
# Epoch   8 Batch   94/197   train_loss = 4.360
# Epoch   8 Batch  104/197   train_loss = 4.177
# Epoch   8 Batch  114/197   train_loss = 4.365
# Epoch   8 Batch  124/197   train_loss = 4.233
# Epoch   8 Batch  134/197   train_loss = 4.254
# Epoch   8 Batch  144/197   train_loss = 4.243
# Epoch   8 Batch  154/197   train_loss = 4.258
# Epoch   8 Batch  164/197   train_loss = 4.327
# Epoch   8 Batch  174/197   train_loss = 4.316
# Epoch   8 Batch  184/197   train_loss = 4.237
# Epoch   8 Batch  194/197   train_loss = 4.286
# Epoch   9 Batch    7/197   train_loss = 4.200
# Epoch   9 Batch   17/197   train_loss = 4.250
# Epoch   9 Batch   27/197   train_loss = 4.325
# Epoch   9 Batch   37/197   train_loss = 4.247
# Epoch   9 Batch   47/197   train_loss = 4.146
# Epoch   9 Batch   57/197   train_loss = 4.212
# Epoch   9 Batch   67/197   train_loss = 4.254
# Epoch   9 Batch   77/197   train_loss = 4.212
# Epoch   9 Batch   87/197   train_loss = 4.156
# Epoch   9 Batch   97/197   train_loss = 4.243
# Epoch   9 Batch  107/197   train_loss = 4.095
# Epoch   9 Batch  117/197   train_loss = 4.137
# Epoch   9 Batch  127/197   train_loss = 4.305
# Epoch   9 Batch  137/197   train_loss = 4.105
# Epoch   9 Batch  147/197   train_loss = 4.277
# Epoch   9 Batch  157/197   train_loss = 4.160
# Epoch   9 Batch  167/197   train_loss = 4.212
# Epoch   9 Batch  177/197   train_loss = 4.172
# Epoch   9 Batch  187/197   train_loss = 4.131
# Epoch  10 Batch    0/197   train_loss = 4.169
# Epoch  10 Batch   10/197   train_loss = 4.268
# Epoch  10 Batch   20/197   train_loss = 4.143
# Epoch  10 Batch   30/197   train_loss = 4.250
# Epoch  10 Batch   40/197   train_loss = 4.259
# Epoch  10 Batch   50/197   train_loss = 4.282
# Epoch  10 Batch   60/197   train_loss = 4.168
# Epoch  10 Batch   70/197   train_loss = 4.233
# Epoch  10 Batch   80/197   train_loss = 4.343
# Epoch  10 Batch   90/197   train_loss = 4.149
# Epoch  10 Batch  100/197   train_loss = 4.228
# Epoch  10 Batch  110/197   train_loss = 4.244
# Epoch  10 Batch  120/197   train_loss = 4.249
# Epoch  10 Batch  130/197   train_loss = 4.220
# Epoch  10 Batch  140/197   train_loss = 4.211
# Epoch  10 Batch  150/197   train_loss = 4.132
# Epoch  10 Batch  160/197   train_loss = 4.221
# Epoch  10 Batch  170/197   train_loss = 4.099
# Epoch  10 Batch  180/197   train_loss = 4.088
# Epoch  10 Batch  190/197   train_loss = 4.199
# Epoch  11 Batch    3/197   train_loss = 4.285
# Epoch  11 Batch   13/197   train_loss = 4.192
# Epoch  11 Batch   23/197   train_loss = 4.154
# Epoch  11 Batch   33/197   train_loss = 4.072
# Epoch  11 Batch   43/197   train_loss = 4.198
# Epoch  11 Batch   53/197   train_loss = 4.170
# Epoch  11 Batch   63/197   train_loss = 4.171
# Epoch  11 Batch   73/197   train_loss = 4.088
# Epoch  11 Batch   83/197   train_loss = 4.201
# Epoch  11 Batch   93/197   train_loss = 4.192
# Epoch  11 Batch  103/197   train_loss = 4.110
# Epoch  11 Batch  113/197   train_loss = 4.121
# Epoch  11 Batch  123/197   train_loss = 4.193
# Epoch  11 Batch  133/197   train_loss = 4.117
# Epoch  11 Batch  143/197   train_loss = 4.204
# Epoch  11 Batch  153/197   train_loss = 4.217
# Epoch  11 Batch  163/197   train_loss = 4.181
# Epoch  11 Batch  173/197   train_loss = 4.047
# Epoch  11 Batch  183/197   train_loss = 4.022
# Epoch  11 Batch  193/197   train_loss = 4.036
# Epoch  12 Batch    6/197   train_loss = 4.077
# Epoch  12 Batch   16/197   train_loss = 4.072
# Epoch  12 Batch   26/197   train_loss = 4.061
# Epoch  12 Batch   36/197   train_loss = 4.150
# Epoch  12 Batch   46/197   train_loss = 4.089
# Epoch  12 Batch   56/197   train_loss = 4.064
# Epoch  12 Batch   66/197   train_loss = 4.032
# Epoch  12 Batch   76/197   train_loss = 4.194
# Epoch  12 Batch   86/197   train_loss = 4.087
# Epoch  12 Batch   96/197   train_loss = 4.148
# Epoch  12 Batch  106/197   train_loss = 4.093
# Epoch  12 Batch  116/197   train_loss = 4.142
# Epoch  12 Batch  126/197   train_loss = 4.151
# Epoch  12 Batch  136/197   train_loss = 4.121
# Epoch  12 Batch  146/197   train_loss = 4.101
# Epoch  12 Batch  156/197   train_loss = 4.120
# Epoch  12 Batch  166/197   train_loss = 4.103
# Epoch  12 Batch  176/197   train_loss = 4.081
# Epoch  12 Batch  186/197   train_loss = 4.151
# Epoch  12 Batch  196/197   train_loss = 4.114
# Epoch  13 Batch    9/197   train_loss = 4.089
# Epoch  13 Batch   19/197   train_loss = 4.066
# Epoch  13 Batch   29/197   train_loss = 4.055
# Epoch  13 Batch   39/197   train_loss = 4.137
# Epoch  13 Batch   49/197   train_loss = 4.071
# Epoch  13 Batch   59/197   train_loss = 4.170
# Epoch  13 Batch   69/197   train_loss = 4.119
# Epoch  13 Batch   79/197   train_loss = 3.993
# Epoch  13 Batch   89/197   train_loss = 4.046
# Epoch  13 Batch   99/197   train_loss = 4.114
# Epoch  13 Batch  109/197   train_loss = 4.150
# Epoch  13 Batch  119/197   train_loss = 3.978
# Epoch  13 Batch  129/197   train_loss = 4.112
# Epoch  13 Batch  139/197   train_loss = 4.003
# Epoch  13 Batch  149/197   train_loss = 4.030
# Epoch  13 Batch  159/197   train_loss = 3.976
# Epoch  13 Batch  169/197   train_loss = 3.945
# Epoch  13 Batch  179/197   train_loss = 4.055
# Epoch  13 Batch  189/197   train_loss = 3.969
# Epoch  14 Batch    2/197   train_loss = 4.060
# Epoch  14 Batch   12/197   train_loss = 4.079
# Epoch  14 Batch   22/197   train_loss = 4.098
# Epoch  14 Batch   32/197   train_loss = 3.982
# Epoch  14 Batch   42/197   train_loss = 4.055
# Epoch  14 Batch   52/197   train_loss = 4.058
# Epoch  14 Batch   62/197   train_loss = 4.101
# Epoch  14 Batch   72/197   train_loss = 4.041
# Epoch  14 Batch   82/197   train_loss = 4.060
# Epoch  14 Batch   92/197   train_loss = 4.038
# Epoch  14 Batch  102/197   train_loss = 4.095
# Epoch  14 Batch  112/197   train_loss = 3.933
# Epoch  14 Batch  122/197   train_loss = 3.995
# Epoch  14 Batch  132/197   train_loss = 4.078
# Epoch  14 Batch  142/197   train_loss = 4.050
# Epoch  14 Batch  152/197   train_loss = 4.031
# Epoch  14 Batch  162/197   train_loss = 4.073
# Epoch  14 Batch  172/197   train_loss = 4.119
# Epoch  14 Batch  182/197   train_loss = 4.009
# Epoch  14 Batch  192/197   train_loss = 4.050
# Epoch  15 Batch    5/197   train_loss = 4.096
# Epoch  15 Batch   15/197   train_loss = 4.053
# Epoch  15 Batch   25/197   train_loss = 4.041
# Epoch  15 Batch   35/197   train_loss = 3.985
# Epoch  15 Batch   45/197   train_loss = 3.959
# Epoch  15 Batch   55/197   train_loss = 4.036
# Epoch  15 Batch   65/197   train_loss = 4.112
# Epoch  15 Batch   75/197   train_loss = 3.980
# Epoch  15 Batch   85/197   train_loss = 3.983
# Epoch  15 Batch   95/197   train_loss = 4.013
# Epoch  15 Batch  105/197   train_loss = 4.021
# Epoch  15 Batch  115/197   train_loss = 4.042
# Epoch  15 Batch  125/197   train_loss = 4.145
# Epoch  15 Batch  135/197   train_loss = 4.085
# Epoch  15 Batch  145/197   train_loss = 4.103
# Epoch  15 Batch  155/197   train_loss = 4.098
# Epoch  15 Batch  165/197   train_loss = 4.092
# Epoch  15 Batch  175/197   train_loss = 3.992
# Epoch  15 Batch  185/197   train_loss = 4.091
# Epoch  15 Batch  195/197   train_loss = 3.975
# Epoch  16 Batch    8/197   train_loss = 4.088
# Epoch  16 Batch   18/197   train_loss = 4.069
# Epoch  16 Batch   28/197   train_loss = 3.960
# Epoch  16 Batch   38/197   train_loss = 4.024
# Epoch  16 Batch   48/197   train_loss = 4.064
# Epoch  16 Batch   58/197   train_loss = 3.907
# Epoch  16 Batch   68/197   train_loss = 4.040
# Epoch  16 Batch   78/197   train_loss = 4.014
# Epoch  16 Batch   88/197   train_loss = 3.928
# Epoch  16 Batch   98/197   train_loss = 3.905
# Epoch  16 Batch  108/197   train_loss = 4.065
# Epoch  16 Batch  118/197   train_loss = 4.006
# Epoch  16 Batch  128/197   train_loss = 3.947
# Epoch  16 Batch  138/197   train_loss = 4.093
# Epoch  16 Batch  148/197   train_loss = 3.921
# Epoch  16 Batch  158/197   train_loss = 4.058
# Epoch  16 Batch  168/197   train_loss = 3.993
# Epoch  16 Batch  178/197   train_loss = 3.926
# Epoch  16 Batch  188/197   train_loss = 4.039
# Epoch  17 Batch    1/197   train_loss = 3.970
# Epoch  17 Batch   11/197   train_loss = 3.903
# Epoch  17 Batch   21/197   train_loss = 3.991
# Epoch  17 Batch   31/197   train_loss = 4.052
# Epoch  17 Batch   41/197   train_loss = 3.884
# Epoch  17 Batch   51/197   train_loss = 4.018
# Epoch  17 Batch   61/197   train_loss = 4.010
# Epoch  17 Batch   71/197   train_loss = 3.951
# Epoch  17 Batch   81/197   train_loss = 4.002
# Epoch  17 Batch   91/197   train_loss = 3.970
# Epoch  17 Batch  101/197   train_loss = 3.918
# Epoch  17 Batch  111/197   train_loss = 3.958
# Epoch  17 Batch  121/197   train_loss = 3.971
# Epoch  17 Batch  131/197   train_loss = 3.950
# Epoch  17 Batch  141/197   train_loss = 3.921
# Epoch  17 Batch  151/197   train_loss = 3.998
# Epoch  17 Batch  161/197   train_loss = 4.026
# Epoch  17 Batch  171/197   train_loss = 3.942
# Epoch  17 Batch  181/197   train_loss = 3.934
# Epoch  17 Batch  191/197   train_loss = 3.913
# Epoch  18 Batch    4/197   train_loss = 4.038
# Epoch  18 Batch   14/197   train_loss = 3.999
# Epoch  18 Batch   24/197   train_loss = 3.864
# Epoch  18 Batch   34/197   train_loss = 3.919
# Epoch  18 Batch   44/197   train_loss = 4.126
# Epoch  18 Batch   54/197   train_loss = 4.003
# Epoch  18 Batch   64/197   train_loss = 4.007
# Epoch  18 Batch   74/197   train_loss = 3.999
# Epoch  18 Batch   84/197   train_loss = 3.975
# Epoch  18 Batch   94/197   train_loss = 4.047
# Epoch  18 Batch  104/197   train_loss = 3.860
# Epoch  18 Batch  114/197   train_loss = 4.056
# Epoch  18 Batch  124/197   train_loss = 3.938
# Epoch  18 Batch  134/197   train_loss = 3.972
# Epoch  18 Batch  144/197   train_loss = 3.973
# Epoch  18 Batch  154/197   train_loss = 3.981
# Epoch  18 Batch  164/197   train_loss = 4.104
# Epoch  18 Batch  174/197   train_loss = 4.015
# Epoch  18 Batch  184/197   train_loss = 3.936
# Epoch  18 Batch  194/197   train_loss = 4.054
# Epoch  19 Batch    7/197   train_loss = 3.927
# Epoch  19 Batch   17/197   train_loss = 3.968
# Epoch  19 Batch   27/197   train_loss = 4.072
# Epoch  19 Batch   37/197   train_loss = 3.956
# Epoch  19 Batch   47/197   train_loss = 3.865
# Epoch  19 Batch   57/197   train_loss = 3.970
# Epoch  19 Batch   67/197   train_loss = 4.051
# Epoch  19 Batch   77/197   train_loss = 3.954
# Epoch  19 Batch   87/197   train_loss = 3.900
# Epoch  19 Batch   97/197   train_loss = 3.980
# Epoch  19 Batch  107/197   train_loss = 3.852
# Epoch  19 Batch  117/197   train_loss = 3.884
# Epoch  19 Batch  127/197   train_loss = 4.037
# Epoch  19 Batch  137/197   train_loss = 3.872
# Epoch  19 Batch  147/197   train_loss = 3.979
# Epoch  19 Batch  157/197   train_loss = 3.900
# Epoch  19 Batch  167/197   train_loss = 3.943
# Epoch  19 Batch  177/197   train_loss = 3.932
# Epoch  19 Batch  187/197   train_loss = 3.870
# Epoch  20 Batch    0/197   train_loss = 3.907
# Epoch  20 Batch   10/197   train_loss = 3.967
# Epoch  20 Batch   20/197   train_loss = 3.867
# Epoch  20 Batch   30/197   train_loss = 3.990
# Epoch  20 Batch   40/197   train_loss = 4.014
# Epoch  20 Batch   50/197   train_loss = 4.057
# Epoch  20 Batch   60/197   train_loss = 3.919
# Epoch  20 Batch   70/197   train_loss = 4.003
# Epoch  20 Batch   80/197   train_loss = 4.062
# Epoch  20 Batch   90/197   train_loss = 3.905
# Epoch  20 Batch  100/197   train_loss = 3.983
# Epoch  20 Batch  110/197   train_loss = 3.963
# Epoch  20 Batch  120/197   train_loss = 3.958
# Epoch  20 Batch  130/197   train_loss = 4.001
# Epoch  20 Batch  140/197   train_loss = 3.940
# Epoch  20 Batch  150/197   train_loss = 3.878
# Epoch  20 Batch  160/197   train_loss = 4.026
# Epoch  20 Batch  170/197   train_loss = 3.882
# Epoch  20 Batch  180/197   train_loss = 3.884
# Epoch  20 Batch  190/197   train_loss = 3.913
# Epoch  21 Batch    3/197   train_loss = 4.028
# Epoch  21 Batch   13/197   train_loss = 3.995
# Epoch  21 Batch   23/197   train_loss = 3.960
# Epoch  21 Batch   33/197   train_loss = 3.889
# Epoch  21 Batch   43/197   train_loss = 3.948
# Epoch  21 Batch   53/197   train_loss = 3.954
# Epoch  21 Batch   63/197   train_loss = 3.941
# Epoch  21 Batch   73/197   train_loss = 3.910
# Epoch  21 Batch   83/197   train_loss = 3.960
# Epoch  21 Batch   93/197   train_loss = 3.971
# Epoch  21 Batch  103/197   train_loss = 3.901
# Epoch  21 Batch  113/197   train_loss = 3.911
# Epoch  21 Batch  123/197   train_loss = 4.007
# Epoch  21 Batch  133/197   train_loss = 3.885
# Epoch  21 Batch  143/197   train_loss = 3.971
# Epoch  21 Batch  153/197   train_loss = 4.010
# Epoch  21 Batch  163/197   train_loss = 4.000
# Epoch  21 Batch  173/197   train_loss = 3.836
# Epoch  21 Batch  183/197   train_loss = 3.788
# Epoch  21 Batch  193/197   train_loss = 3.834
# Epoch  22 Batch    6/197   train_loss = 3.909
# Epoch  22 Batch   16/197   train_loss = 3.876
# Epoch  22 Batch   26/197   train_loss = 3.860
# Epoch  22 Batch   36/197   train_loss = 3.965
# Epoch  22 Batch   46/197   train_loss = 3.912
# Epoch  22 Batch   56/197   train_loss = 3.878
# Epoch  22 Batch   66/197   train_loss = 3.867
# Epoch  22 Batch   76/197   train_loss = 4.010
# Epoch  22 Batch   86/197   train_loss = 3.908
# Epoch  22 Batch   96/197   train_loss = 3.974
# Epoch  22 Batch  106/197   train_loss = 3.911
# Epoch  22 Batch  116/197   train_loss = 3.967
# Epoch  22 Batch  126/197   train_loss = 3.922
# Epoch  22 Batch  136/197   train_loss = 3.919
# Epoch  22 Batch  146/197   train_loss = 3.896
# Epoch  22 Batch  156/197   train_loss = 3.964
# Epoch  22 Batch  166/197   train_loss = 3.926
# Epoch  22 Batch  176/197   train_loss = 3.895
# Epoch  22 Batch  186/197   train_loss = 3.908
# Epoch  22 Batch  196/197   train_loss = 3.915
# Epoch  23 Batch    9/197   train_loss = 3.894
# Epoch  23 Batch   19/197   train_loss = 3.923
# Epoch  23 Batch   29/197   train_loss = 3.911
# Epoch  23 Batch   39/197   train_loss = 3.959
# Epoch  23 Batch   49/197   train_loss = 3.898
# Epoch  23 Batch   59/197   train_loss = 3.974
# Epoch  23 Batch   69/197   train_loss = 3.911
# Epoch  23 Batch   79/197   train_loss = 3.841
# Epoch  23 Batch   89/197   train_loss = 3.867
# Epoch  23 Batch   99/197   train_loss = 3.964
# Epoch  23 Batch  109/197   train_loss = 4.026
# Epoch  23 Batch  119/197   train_loss = 3.793
# Epoch  23 Batch  129/197   train_loss = 3.904
# Epoch  23 Batch  139/197   train_loss = 3.813
# Epoch  23 Batch  149/197   train_loss = 3.819
# Epoch  23 Batch  159/197   train_loss = 3.823
# Epoch  23 Batch  169/197   train_loss = 3.814
# Epoch  23 Batch  179/197   train_loss = 3.871
# Epoch  23 Batch  189/197   train_loss = 3.796
# Epoch  24 Batch    2/197   train_loss = 3.834
# Epoch  24 Batch   12/197   train_loss = 3.876
# Epoch  24 Batch   22/197   train_loss = 3.899
# Epoch  24 Batch   32/197   train_loss = 3.815
# Epoch  24 Batch   42/197   train_loss = 3.840
# Epoch  24 Batch   52/197   train_loss = 3.917
# Epoch  24 Batch   62/197   train_loss = 3.918
# Epoch  24 Batch   72/197   train_loss = 3.894
# Epoch  24 Batch   82/197   train_loss = 3.998
# Epoch  24 Batch   92/197   train_loss = 3.911
# Epoch  24 Batch  102/197   train_loss = 3.927
# Epoch  24 Batch  112/197   train_loss = 3.788
# Epoch  24 Batch  122/197   train_loss = 3.825
# Epoch  24 Batch  132/197   train_loss = 3.933
# Epoch  24 Batch  142/197   train_loss = 3.893
# Epoch  24 Batch  152/197   train_loss = 3.862
# Epoch  24 Batch  162/197   train_loss = 3.945
# Epoch  24 Batch  172/197   train_loss = 3.962
# Epoch  24 Batch  182/197   train_loss = 3.870
# Epoch  24 Batch  192/197   train_loss = 3.900
# Epoch  25 Batch    5/197   train_loss = 3.885
# Epoch  25 Batch   15/197   train_loss = 3.887
# Epoch  25 Batch   25/197   train_loss = 3.911
# Epoch  25 Batch   35/197   train_loss = 3.885
# Epoch  25 Batch   45/197   train_loss = 3.792
# Epoch  25 Batch   55/197   train_loss = 3.884
# Epoch  25 Batch   65/197   train_loss = 3.933
# Epoch  25 Batch   75/197   train_loss = 3.855
# Epoch  25 Batch   85/197   train_loss = 3.875
# Epoch  25 Batch   95/197   train_loss = 3.884
# Epoch  25 Batch  105/197   train_loss = 3.887
# Epoch  25 Batch  115/197   train_loss = 3.943
# Epoch  25 Batch  125/197   train_loss = 3.977
# Epoch  25 Batch  135/197   train_loss = 3.923
# Epoch  25 Batch  145/197   train_loss = 3.960
# Epoch  25 Batch  155/197   train_loss = 3.945
# Epoch  25 Batch  165/197   train_loss = 3.962
# Epoch  25 Batch  175/197   train_loss = 3.878
# Epoch  25 Batch  185/197   train_loss = 3.907
# Epoch  25 Batch  195/197   train_loss = 3.862
# Epoch  26 Batch    8/197   train_loss = 3.928
# Epoch  26 Batch   18/197   train_loss = 3.932
# Epoch  26 Batch   28/197   train_loss = 3.861
# Epoch  26 Batch   38/197   train_loss = 3.847
# Epoch  26 Batch   48/197   train_loss = 3.932
# Epoch  26 Batch   58/197   train_loss = 3.772
# Epoch  26 Batch   68/197   train_loss = 3.857
# Epoch  26 Batch   78/197   train_loss = 3.866
# Epoch  26 Batch   88/197   train_loss = 3.801
# Epoch  26 Batch   98/197   train_loss = 3.776
# Epoch  26 Batch  108/197   train_loss = 3.946
# Epoch  26 Batch  118/197   train_loss = 3.876
# Epoch  26 Batch  128/197   train_loss = 3.829
# Epoch  26 Batch  138/197   train_loss = 3.931
# Epoch  26 Batch  148/197   train_loss = 3.788
# Epoch  26 Batch  158/197   train_loss = 3.890
# Epoch  26 Batch  168/197   train_loss = 3.904
# Epoch  26 Batch  178/197   train_loss = 3.801
# Epoch  26 Batch  188/197   train_loss = 3.876
# Epoch  27 Batch    1/197   train_loss = 3.813
# Epoch  27 Batch   11/197   train_loss = 3.805
# Epoch  27 Batch   21/197   train_loss = 3.845
# Epoch  27 Batch   31/197   train_loss = 3.897
# Epoch  27 Batch   41/197   train_loss = 3.731
# Epoch  27 Batch   51/197   train_loss = 3.894
# Epoch  27 Batch   61/197   train_loss = 3.876
# Epoch  27 Batch   71/197   train_loss = 3.797
# Epoch  27 Batch   81/197   train_loss = 3.867
# Epoch  27 Batch   91/197   train_loss = 3.878
# Epoch  27 Batch  101/197   train_loss = 3.784
# Epoch  27 Batch  111/197   train_loss = 3.839
# Epoch  27 Batch  121/197   train_loss = 3.849
# Epoch  27 Batch  131/197   train_loss = 3.857
# Epoch  27 Batch  141/197   train_loss = 3.786
# Epoch  27 Batch  151/197   train_loss = 3.821
# Epoch  27 Batch  161/197   train_loss = 3.936
# Epoch  27 Batch  171/197   train_loss = 3.786
# Epoch  27 Batch  181/197   train_loss = 3.843
# Epoch  27 Batch  191/197   train_loss = 3.791
# Epoch  28 Batch    4/197   train_loss = 3.886
# Epoch  28 Batch   14/197   train_loss = 3.832
# Epoch  28 Batch   24/197   train_loss = 3.798
# Epoch  28 Batch   34/197   train_loss = 3.800
# Epoch  28 Batch   44/197   train_loss = 3.985
# Epoch  28 Batch   54/197   train_loss = 3.845
# Epoch  28 Batch   64/197   train_loss = 3.857
# Epoch  28 Batch   74/197   train_loss = 3.846
# Epoch  28 Batch   84/197   train_loss = 3.858
# Epoch  28 Batch   94/197   train_loss = 3.895
# Epoch  28 Batch  104/197   train_loss = 3.788
# Epoch  28 Batch  114/197   train_loss = 3.919
# Epoch  28 Batch  124/197   train_loss = 3.803
# Epoch  28 Batch  134/197   train_loss = 3.818
# Epoch  28 Batch  144/197   train_loss = 3.817
# Epoch  28 Batch  154/197   train_loss = 3.806
# Epoch  28 Batch  164/197   train_loss = 3.988
# Epoch  28 Batch  174/197   train_loss = 3.886
# Epoch  28 Batch  184/197   train_loss = 3.820
# Epoch  28 Batch  194/197   train_loss = 3.921
# Epoch  29 Batch    7/197   train_loss = 3.783
# Epoch  29 Batch   17/197   train_loss = 3.864
# Epoch  29 Batch   27/197   train_loss = 3.935
# Epoch  29 Batch   37/197   train_loss = 3.832
# Epoch  29 Batch   47/197   train_loss = 3.711
# Epoch  29 Batch   57/197   train_loss = 3.861
# Epoch  29 Batch   67/197   train_loss = 3.873
# Epoch  29 Batch   77/197   train_loss = 3.819
# Epoch  29 Batch   87/197   train_loss = 3.745
# Epoch  29 Batch   97/197   train_loss = 3.872
# Epoch  29 Batch  107/197   train_loss = 3.746
# Epoch  29 Batch  117/197   train_loss = 3.746
# Epoch  29 Batch  127/197   train_loss = 3.933
# Epoch  29 Batch  137/197   train_loss = 3.750
# Epoch  29 Batch  147/197   train_loss = 3.867
# Epoch  29 Batch  157/197   train_loss = 3.725
# Epoch  29 Batch  167/197   train_loss = 3.889
# Epoch  29 Batch  177/197   train_loss = 3.832
# Epoch  29 Batch  187/197   train_loss = 3.738
# Epoch  30 Batch    0/197   train_loss = 3.759
# Epoch  30 Batch   10/197   train_loss = 3.891
# Epoch  30 Batch   20/197   train_loss = 3.804
# Epoch  30 Batch   30/197   train_loss = 3.908
# Epoch  30 Batch   40/197   train_loss = 3.906
# Epoch  30 Batch   50/197   train_loss = 3.933
# Epoch  30 Batch   60/197   train_loss = 3.799
# Epoch  30 Batch   70/197   train_loss = 3.887
# Epoch  30 Batch   80/197   train_loss = 3.947
# Epoch  30 Batch   90/197   train_loss = 3.796
# Epoch  30 Batch  100/197   train_loss = 3.884
# Epoch  30 Batch  110/197   train_loss = 3.889
# Epoch  30 Batch  120/197   train_loss = 3.846
# Epoch  30 Batch  130/197   train_loss = 3.866
# Epoch  30 Batch  140/197   train_loss = 3.825
# Epoch  30 Batch  150/197   train_loss = 3.799
# Epoch  30 Batch  160/197   train_loss = 3.869
# Epoch  30 Batch  170/197   train_loss = 3.795
# Epoch  30 Batch  180/197   train_loss = 3.835
# Epoch  30 Batch  190/197   train_loss = 3.801
# Epoch  31 Batch    3/197   train_loss = 3.889
# Epoch  31 Batch   13/197   train_loss = 3.897
# Epoch  31 Batch   23/197   train_loss = 3.866
# Epoch  31 Batch   33/197   train_loss = 3.804
# Epoch  31 Batch   43/197   train_loss = 3.840
# Epoch  31 Batch   53/197   train_loss = 3.840
# Epoch  31 Batch   63/197   train_loss = 3.807
# Epoch  31 Batch   73/197   train_loss = 3.794
# Epoch  31 Batch   83/197   train_loss = 3.834
# Epoch  31 Batch   93/197   train_loss = 3.826
# Epoch  31 Batch  103/197   train_loss = 3.784
# Epoch  31 Batch  113/197   train_loss = 3.856
# Epoch  31 Batch  123/197   train_loss = 3.904
# Epoch  31 Batch  133/197   train_loss = 3.813
# Epoch  31 Batch  143/197   train_loss = 3.915
# Epoch  31 Batch  153/197   train_loss = 3.922
# Epoch  31 Batch  163/197   train_loss = 3.861
# Epoch  31 Batch  173/197   train_loss = 3.795
# Epoch  31 Batch  183/197   train_loss = 3.714
# Epoch  31 Batch  193/197   train_loss = 3.741
# Epoch  32 Batch    6/197   train_loss = 3.809
# Epoch  32 Batch   16/197   train_loss = 3.777
# Epoch  32 Batch   26/197   train_loss = 3.770
# Epoch  32 Batch   36/197   train_loss = 3.836
# Epoch  32 Batch   46/197   train_loss = 3.819
# Epoch  32 Batch   56/197   train_loss = 3.768
# Epoch  32 Batch   66/197   train_loss = 3.749
# Epoch  32 Batch   76/197   train_loss = 3.917
# Epoch  32 Batch   86/197   train_loss = 3.799
# Epoch  32 Batch   96/197   train_loss = 3.854
# Epoch  32 Batch  106/197   train_loss = 3.817
# Epoch  32 Batch  116/197   train_loss = 3.912
# Epoch  32 Batch  126/197   train_loss = 3.829
# Epoch  32 Batch  136/197   train_loss = 3.857
# Epoch  32 Batch  146/197   train_loss = 3.843
# Epoch  32 Batch  156/197   train_loss = 3.854
# Epoch  32 Batch  166/197   train_loss = 3.831
# Epoch  32 Batch  176/197   train_loss = 3.842
# Epoch  32 Batch  186/197   train_loss = 3.832
# Epoch  32 Batch  196/197   train_loss = 3.829
# Epoch  33 Batch    9/197   train_loss = 3.809
# Epoch  33 Batch   19/197   train_loss = 3.820
# Epoch  33 Batch   29/197   train_loss = 3.847
# Epoch  33 Batch   39/197   train_loss = 3.897
# Epoch  33 Batch   49/197   train_loss = 3.819
# Epoch  33 Batch   59/197   train_loss = 3.854
# Epoch  33 Batch   69/197   train_loss = 3.881
# Epoch  33 Batch   79/197   train_loss = 3.712
# Epoch  33 Batch   89/197   train_loss = 3.757
# Epoch  33 Batch   99/197   train_loss = 3.798
# Epoch  33 Batch  109/197   train_loss = 3.903
# Epoch  33 Batch  119/197   train_loss = 3.726
# Epoch  33 Batch  129/197   train_loss = 3.811
# Epoch  33 Batch  139/197   train_loss = 3.769
# Epoch  33 Batch  149/197   train_loss = 3.762
# Epoch  33 Batch  159/197   train_loss = 3.731
# Epoch  33 Batch  169/197   train_loss = 3.716
# Epoch  33 Batch  179/197   train_loss = 3.837
# Epoch  33 Batch  189/197   train_loss = 3.753
# Epoch  34 Batch    2/197   train_loss = 3.787
# Epoch  34 Batch   12/197   train_loss = 3.793
# Epoch  34 Batch   22/197   train_loss = 3.829
# Epoch  34 Batch   32/197   train_loss = 3.744
# Epoch  34 Batch   42/197   train_loss = 3.791
# Epoch  34 Batch   52/197   train_loss = 3.810
# Epoch  34 Batch   62/197   train_loss = 3.814
# Epoch  34 Batch   72/197   train_loss = 3.817
# Epoch  34 Batch   82/197   train_loss = 3.862
# Epoch  34 Batch   92/197   train_loss = 3.791
# Epoch  34 Batch  102/197   train_loss = 3.823
# Epoch  34 Batch  112/197   train_loss = 3.715
# Epoch  34 Batch  122/197   train_loss = 3.784
# Epoch  34 Batch  132/197   train_loss = 3.895
# Epoch  34 Batch  142/197   train_loss = 3.795
# Epoch  34 Batch  152/197   train_loss = 3.773
# Epoch  34 Batch  162/197   train_loss = 3.837
# Epoch  34 Batch  172/197   train_loss = 3.865
# Epoch  34 Batch  182/197   train_loss = 3.806
# Epoch  34 Batch  192/197   train_loss = 3.825
# Epoch  35 Batch    5/197   train_loss = 3.816
# Epoch  35 Batch   15/197   train_loss = 3.767
# Epoch  35 Batch   25/197   train_loss = 3.847
# Epoch  35 Batch   35/197   train_loss = 3.809
# Epoch  35 Batch   45/197   train_loss = 3.740
# Epoch  35 Batch   55/197   train_loss = 3.800
# Epoch  35 Batch   65/197   train_loss = 3.840
# Epoch  35 Batch   75/197   train_loss = 3.769
# Epoch  35 Batch   85/197   train_loss = 3.761
# Epoch  35 Batch   95/197   train_loss = 3.776
# Epoch  35 Batch  105/197   train_loss = 3.825
# Epoch  35 Batch  115/197   train_loss = 3.886
# Epoch  35 Batch  125/197   train_loss = 3.900
# Epoch  35 Batch  135/197   train_loss = 3.808
# Epoch  35 Batch  145/197   train_loss = 3.862
# Epoch  35 Batch  155/197   train_loss = 3.901
# Epoch  35 Batch  165/197   train_loss = 3.869
# Epoch  35 Batch  175/197   train_loss = 3.773
# Epoch  35 Batch  185/197   train_loss = 3.885
# Epoch  35 Batch  195/197   train_loss = 3.770
# Epoch  36 Batch    8/197   train_loss = 3.844
# Epoch  36 Batch   18/197   train_loss = 3.811
# Epoch  36 Batch   28/197   train_loss = 3.766
# Epoch  36 Batch   38/197   train_loss = 3.781
# Epoch  36 Batch   48/197   train_loss = 3.846
# Epoch  36 Batch   58/197   train_loss = 3.680
# Epoch  36 Batch   68/197   train_loss = 3.811
# Epoch  36 Batch   78/197   train_loss = 3.831
# Epoch  36 Batch   88/197   train_loss = 3.721
# Epoch  36 Batch   98/197   train_loss = 3.707
# Epoch  36 Batch  108/197   train_loss = 3.825
# Epoch  36 Batch  118/197   train_loss = 3.827
# Epoch  36 Batch  128/197   train_loss = 3.745
# Epoch  36 Batch  138/197   train_loss = 3.878
# Epoch  36 Batch  148/197   train_loss = 3.712
# Epoch  36 Batch  158/197   train_loss = 3.864
# Epoch  36 Batch  168/197   train_loss = 3.765
# Epoch  36 Batch  178/197   train_loss = 3.714
# Epoch  36 Batch  188/197   train_loss = 3.862
# Epoch  37 Batch    1/197   train_loss = 3.767
# Epoch  37 Batch   11/197   train_loss = 3.680
# Epoch  37 Batch   21/197   train_loss = 3.749
# Epoch  37 Batch   31/197   train_loss = 3.787
# Epoch  37 Batch   41/197   train_loss = 3.626
# Epoch  37 Batch   51/197   train_loss = 3.813
# Epoch  37 Batch   61/197   train_loss = 3.835
# Epoch  37 Batch   71/197   train_loss = 3.769
# Epoch  37 Batch   81/197   train_loss = 3.810
# Epoch  37 Batch   91/197   train_loss = 3.769
# Epoch  37 Batch  101/197   train_loss = 3.659
# Epoch  37 Batch  111/197   train_loss = 3.770
# Epoch  37 Batch  121/197   train_loss = 3.777
# Epoch  37 Batch  131/197   train_loss = 3.790
# Epoch  37 Batch  141/197   train_loss = 3.705
# Epoch  37 Batch  151/197   train_loss = 3.746
# Epoch  37 Batch  161/197   train_loss = 3.838
# Epoch  37 Batch  171/197   train_loss = 3.710
# Epoch  37 Batch  181/197   train_loss = 3.780
# Epoch  37 Batch  191/197   train_loss = 3.754
# Epoch  38 Batch    4/197   train_loss = 3.848
# Epoch  38 Batch   14/197   train_loss = 3.789
# Epoch  38 Batch   24/197   train_loss = 3.739
# Epoch  38 Batch   34/197   train_loss = 3.739
# Epoch  38 Batch   44/197   train_loss = 3.915
# Epoch  38 Batch   54/197   train_loss = 3.789
# Epoch  38 Batch   64/197   train_loss = 3.800
# Epoch  38 Batch   74/197   train_loss = 3.788
# Epoch  38 Batch   84/197   train_loss = 3.829
# Epoch  38 Batch   94/197   train_loss = 3.811
# Epoch  38 Batch  104/197   train_loss = 3.733
# Epoch  38 Batch  114/197   train_loss = 3.892
# Epoch  38 Batch  124/197   train_loss = 3.768
# Epoch  38 Batch  134/197   train_loss = 3.809
# Epoch  38 Batch  144/197   train_loss = 3.751
# Epoch  38 Batch  154/197   train_loss = 3.767
# Epoch  38 Batch  164/197   train_loss = 3.878
# Epoch  38 Batch  174/197   train_loss = 3.783
# Epoch  38 Batch  184/197   train_loss = 3.785
# Epoch  38 Batch  194/197   train_loss = 3.824
# Epoch  39 Batch    7/197   train_loss = 3.737
# Epoch  39 Batch   17/197   train_loss = 3.764
# Epoch  39 Batch   27/197   train_loss = 3.849
# Epoch  39 Batch   37/197   train_loss = 3.809
# Epoch  39 Batch   47/197   train_loss = 3.678
# Epoch  39 Batch   57/197   train_loss = 3.810
# Epoch  39 Batch   67/197   train_loss = 3.835
# Epoch  39 Batch   77/197   train_loss = 3.818
# Epoch  39 Batch   87/197   train_loss = 3.674
# Epoch  39 Batch   97/197   train_loss = 3.792
# Epoch  39 Batch  107/197   train_loss = 3.724
# Epoch  39 Batch  117/197   train_loss = 3.770
# Epoch  39 Batch  127/197   train_loss = 3.868
# Epoch  39 Batch  137/197   train_loss = 3.715
# Epoch  39 Batch  147/197   train_loss = 3.818
# Epoch  39 Batch  157/197   train_loss = 3.730
# Epoch  39 Batch  167/197   train_loss = 3.820
# Epoch  39 Batch  177/197   train_loss = 3.756
# Epoch  39 Batch  187/197   train_loss = 3.698
# Epoch  40 Batch    0/197   train_loss = 3.724
# Epoch  40 Batch   10/197   train_loss = 3.771
# Epoch  40 Batch   20/197   train_loss = 3.730
# Epoch  40 Batch   30/197   train_loss = 3.827
# Epoch  40 Batch   40/197   train_loss = 3.875
# Epoch  40 Batch   50/197   train_loss = 3.868
# Epoch  40 Batch   60/197   train_loss = 3.733
# Epoch  40 Batch   70/197   train_loss = 3.821
# Epoch  40 Batch   80/197   train_loss = 3.899
# Epoch  40 Batch   90/197   train_loss = 3.730
# Epoch  40 Batch  100/197   train_loss = 3.832
# Epoch  40 Batch  110/197   train_loss = 3.789
# Epoch  40 Batch  120/197   train_loss = 3.739
# Epoch  40 Batch  130/197   train_loss = 3.825
# Epoch  40 Batch  140/197   train_loss = 3.788
# Epoch  40 Batch  150/197   train_loss = 3.753
# Epoch  40 Batch  160/197   train_loss = 3.828
# Epoch  40 Batch  170/197   train_loss = 3.686
# Epoch  40 Batch  180/197   train_loss = 3.763
# Epoch  40 Batch  190/197   train_loss = 3.737
# Epoch  41 Batch    3/197   train_loss = 3.852
# Epoch  41 Batch   13/197   train_loss = 3.811
# Epoch  41 Batch   23/197   train_loss = 3.795
# Epoch  41 Batch   33/197   train_loss = 3.727
# Epoch  41 Batch   43/197   train_loss = 3.783
# Epoch  41 Batch   53/197   train_loss = 3.771
# Epoch  41 Batch   63/197   train_loss = 3.761
# Epoch  41 Batch   73/197   train_loss = 3.794
# Epoch  41 Batch   83/197   train_loss = 3.792
# Epoch  41 Batch   93/197   train_loss = 3.785
# Epoch  41 Batch  103/197   train_loss = 3.745
# Epoch  41 Batch  113/197   train_loss = 3.774
# Epoch  41 Batch  123/197   train_loss = 3.830
# Epoch  41 Batch  133/197   train_loss = 3.712
# Epoch  41 Batch  143/197   train_loss = 3.856
# Epoch  41 Batch  153/197   train_loss = 3.865
# Epoch  41 Batch  163/197   train_loss = 3.856
# Epoch  41 Batch  173/197   train_loss = 3.716
# Epoch  41 Batch  183/197   train_loss = 3.652
# Epoch  41 Batch  193/197   train_loss = 3.699
# Epoch  42 Batch    6/197   train_loss = 3.755
# Epoch  42 Batch   16/197   train_loss = 3.679
# Epoch  42 Batch   26/197   train_loss = 3.709
# Epoch  42 Batch   36/197   train_loss = 3.767
# Epoch  42 Batch   46/197   train_loss = 3.762
# Epoch  42 Batch   56/197   train_loss = 3.712
# Epoch  42 Batch   66/197   train_loss = 3.671
# Epoch  42 Batch   76/197   train_loss = 3.840
# Epoch  42 Batch   86/197   train_loss = 3.745
# Epoch  42 Batch   96/197   train_loss = 3.793
# Epoch  42 Batch  106/197   train_loss = 3.750
# Epoch  42 Batch  116/197   train_loss = 3.801
# Epoch  42 Batch  126/197   train_loss = 3.768
# Epoch  42 Batch  136/197   train_loss = 3.796
# Epoch  42 Batch  146/197   train_loss = 3.742
# Epoch  42 Batch  156/197   train_loss = 3.811
# Epoch  42 Batch  166/197   train_loss = 3.806
# Epoch  42 Batch  176/197   train_loss = 3.779
# Epoch  42 Batch  186/197   train_loss = 3.765
# Epoch  42 Batch  196/197   train_loss = 3.800
# Epoch  43 Batch    9/197   train_loss = 3.750
# Epoch  43 Batch   19/197   train_loss = 3.740
# Epoch  43 Batch   29/197   train_loss = 3.770
# Epoch  43 Batch   39/197   train_loss = 3.773
# Epoch  43 Batch   49/197   train_loss = 3.731
# Epoch  43 Batch   59/197   train_loss = 3.857
# Epoch  43 Batch   69/197   train_loss = 3.809
# Epoch  43 Batch   79/197   train_loss = 3.669
# Epoch  43 Batch   89/197   train_loss = 3.685
# Epoch  43 Batch   99/197   train_loss = 3.755
# Epoch  43 Batch  109/197   train_loss = 3.807
# Epoch  43 Batch  119/197   train_loss = 3.683
# Epoch  43 Batch  129/197   train_loss = 3.722
# Epoch  43 Batch  139/197   train_loss = 3.698
# Epoch  43 Batch  149/197   train_loss = 3.705
# Epoch  43 Batch  159/197   train_loss = 3.650
# Epoch  43 Batch  169/197   train_loss = 3.671
# Epoch  43 Batch  179/197   train_loss = 3.763
# Epoch  43 Batch  189/197   train_loss = 3.697
# Epoch  44 Batch    2/197   train_loss = 3.714
# Epoch  44 Batch   12/197   train_loss = 3.762
# Epoch  44 Batch   22/197   train_loss = 3.695
# Epoch  44 Batch   32/197   train_loss = 3.678
# Epoch  44 Batch   42/197   train_loss = 3.718
# Epoch  44 Batch   52/197   train_loss = 3.717
# Epoch  44 Batch   62/197   train_loss = 3.785
# Epoch  44 Batch   72/197   train_loss = 3.740
# Epoch  44 Batch   82/197   train_loss = 3.813
# Epoch  44 Batch   92/197   train_loss = 3.720
# Epoch  44 Batch  102/197   train_loss = 3.785
# Epoch  44 Batch  112/197   train_loss = 3.637
# Epoch  44 Batch  122/197   train_loss = 3.719
# Epoch  44 Batch  132/197   train_loss = 3.778
# Epoch  44 Batch  142/197   train_loss = 3.738
# Epoch  44 Batch  152/197   train_loss = 3.681
# Epoch  44 Batch  162/197   train_loss = 3.766
# Epoch  44 Batch  172/197   train_loss = 3.850
# Epoch  44 Batch  182/197   train_loss = 3.730
# Epoch  44 Batch  192/197   train_loss = 3.807
# Epoch  45 Batch    5/197   train_loss = 3.720
# Epoch  45 Batch   15/197   train_loss = 3.748
# Epoch  45 Batch   25/197   train_loss = 3.768
# Epoch  45 Batch   35/197   train_loss = 3.742
# Epoch  45 Batch   45/197   train_loss = 3.713
# Epoch  45 Batch   55/197   train_loss = 3.716
# Epoch  45 Batch   65/197   train_loss = 3.794
# Epoch  45 Batch   75/197   train_loss = 3.718
# Epoch  45 Batch   85/197   train_loss = 3.702
# Epoch  45 Batch   95/197   train_loss = 3.744
# Epoch  45 Batch  105/197   train_loss = 3.797
# Epoch  45 Batch  115/197   train_loss = 3.817
# Epoch  45 Batch  125/197   train_loss = 3.857
# Epoch  45 Batch  135/197   train_loss = 3.786
# Epoch  45 Batch  145/197   train_loss = 3.788
# Epoch  45 Batch  155/197   train_loss = 3.832
# Epoch  45 Batch  165/197   train_loss = 3.825
# Epoch  45 Batch  175/197   train_loss = 3.716
# Epoch  45 Batch  185/197   train_loss = 3.785
# Epoch  45 Batch  195/197   train_loss = 3.758
# Epoch  46 Batch    8/197   train_loss = 3.783
# Epoch  46 Batch   18/197   train_loss = 3.781
# Epoch  46 Batch   28/197   train_loss = 3.690
# Epoch  46 Batch   38/197   train_loss = 3.768
# Epoch  46 Batch   48/197   train_loss = 3.802
# Epoch  46 Batch   58/197   train_loss = 3.633
# Epoch  46 Batch   68/197   train_loss = 3.730
# Epoch  46 Batch   78/197   train_loss = 3.775
# Epoch  46 Batch   88/197   train_loss = 3.643
# Epoch  46 Batch   98/197   train_loss = 3.633
# Epoch  46 Batch  108/197   train_loss = 3.787
# Epoch  46 Batch  118/197   train_loss = 3.746
# Epoch  46 Batch  128/197   train_loss = 3.681
# Epoch  46 Batch  138/197   train_loss = 3.815
# Epoch  46 Batch  148/197   train_loss = 3.650
# Epoch  46 Batch  158/197   train_loss = 3.794
# Epoch  46 Batch  168/197   train_loss = 3.731
# Epoch  46 Batch  178/197   train_loss = 3.687
# Epoch  46 Batch  188/197   train_loss = 3.792
# Epoch  47 Batch    1/197   train_loss = 3.686
# Epoch  47 Batch   11/197   train_loss = 3.663
# Epoch  47 Batch   21/197   train_loss = 3.688
# Epoch  47 Batch   31/197   train_loss = 3.776
# Epoch  47 Batch   41/197   train_loss = 3.611
# Epoch  47 Batch   51/197   train_loss = 3.750
# Epoch  47 Batch   61/197   train_loss = 3.747
# Epoch  47 Batch   71/197   train_loss = 3.709
# Epoch  47 Batch   81/197   train_loss = 3.758
# Epoch  47 Batch   91/197   train_loss = 3.741
# Epoch  47 Batch  101/197   train_loss = 3.642
# Epoch  47 Batch  111/197   train_loss = 3.721
# Epoch  47 Batch  121/197   train_loss = 3.726
# Epoch  47 Batch  131/197   train_loss = 3.723
# Epoch  47 Batch  141/197   train_loss = 3.643
# Epoch  47 Batch  151/197   train_loss = 3.701
# Epoch  47 Batch  161/197   train_loss = 3.762
# Epoch  47 Batch  171/197   train_loss = 3.707
# Epoch  47 Batch  181/197   train_loss = 3.715
# Epoch  47 Batch  191/197   train_loss = 3.674
# Epoch  48 Batch    4/197   train_loss = 3.784
# Epoch  48 Batch   14/197   train_loss = 3.768
# Epoch  48 Batch   24/197   train_loss = 3.671
# Epoch  48 Batch   34/197   train_loss = 3.691
# Epoch  48 Batch   44/197   train_loss = 3.888
# Epoch  48 Batch   54/197   train_loss = 3.730
# Epoch  48 Batch   64/197   train_loss = 3.729
# Epoch  48 Batch   74/197   train_loss = 3.784
# Epoch  48 Batch   84/197   train_loss = 3.739
# Epoch  48 Batch   94/197   train_loss = 3.800
# Epoch  48 Batch  104/197   train_loss = 3.665
# Epoch  48 Batch  114/197   train_loss = 3.843
# Epoch  48 Batch  124/197   train_loss = 3.723
# Epoch  48 Batch  134/197   train_loss = 3.722
# Epoch  48 Batch  144/197   train_loss = 3.720
# Epoch  48 Batch  154/197   train_loss = 3.726
# Epoch  48 Batch  164/197   train_loss = 3.848
# Epoch  48 Batch  174/197   train_loss = 3.752
# Epoch  48 Batch  184/197   train_loss = 3.727
# Epoch  48 Batch  194/197   train_loss = 3.822
# Epoch  49 Batch    7/197   train_loss = 3.714
# Epoch  49 Batch   17/197   train_loss = 3.741
# Epoch  49 Batch   27/197   train_loss = 3.834
# Epoch  49 Batch   37/197   train_loss = 3.760
# Epoch  49 Batch   47/197   train_loss = 3.607
# Epoch  49 Batch   57/197   train_loss = 3.712
# Epoch  49 Batch   67/197   train_loss = 3.794
# Epoch  49 Batch   77/197   train_loss = 3.758
# Epoch  49 Batch   87/197   train_loss = 3.648
# Epoch  49 Batch   97/197   train_loss = 3.756
# Epoch  49 Batch  107/197   train_loss = 3.642
# Epoch  49 Batch  117/197   train_loss = 3.699
# Epoch  49 Batch  127/197   train_loss = 3.850
# Epoch  49 Batch  137/197   train_loss = 3.650
# Epoch  49 Batch  147/197   train_loss = 3.783
# Epoch  49 Batch  157/197   train_loss = 3.646
# Epoch  49 Batch  167/197   train_loss = 3.750
# Epoch  49 Batch  177/197   train_loss = 3.712
# Epoch  49 Batch  187/197   train_loss = 3.625
# Epoch  50 Batch    0/197   train_loss = 3.678
# Epoch  50 Batch   10/197   train_loss = 3.770
# Epoch  50 Batch   20/197   train_loss = 3.662
# Epoch  50 Batch   30/197   train_loss = 3.764
# Epoch  50 Batch   40/197   train_loss = 3.835
# Epoch  50 Batch   50/197   train_loss = 3.841
# Epoch  50 Batch   60/197   train_loss = 3.686
# Epoch  50 Batch   70/197   train_loss = 3.769
# Epoch  50 Batch   80/197   train_loss = 3.868
# Epoch  50 Batch   90/197   train_loss = 3.722
# Epoch  50 Batch  100/197   train_loss = 3.763
# Epoch  50 Batch  110/197   train_loss = 3.751
# Epoch  50 Batch  120/197   train_loss = 3.719
# Epoch  50 Batch  130/197   train_loss = 3.797
# Epoch  50 Batch  140/197   train_loss = 3.742
# Epoch  50 Batch  150/197   train_loss = 3.716
# Epoch  50 Batch  160/197   train_loss = 3.811
# Epoch  50 Batch  170/197   train_loss = 3.682
# Epoch  50 Batch  180/197   train_loss = 3.672
# Epoch  50 Batch  190/197   train_loss = 3.708
# Epoch  51 Batch    3/197   train_loss = 3.787
# Epoch  51 Batch   13/197   train_loss = 3.729
# Epoch  51 Batch   23/197   train_loss = 3.726
# Epoch  51 Batch   33/197   train_loss = 3.649
# Epoch  51 Batch   43/197   train_loss = 3.766
# Epoch  51 Batch   53/197   train_loss = 3.789
# Epoch  51 Batch   63/197   train_loss = 3.702
# Epoch  51 Batch   73/197   train_loss = 3.710
# Epoch  51 Batch   83/197   train_loss = 3.665
# Epoch  51 Batch   93/197   train_loss = 3.760
# Epoch  51 Batch  103/197   train_loss = 3.694
# Epoch  51 Batch  113/197   train_loss = 3.736
# Epoch  51 Batch  123/197   train_loss = 3.799
# Epoch  51 Batch  133/197   train_loss = 3.699
# Epoch  51 Batch  143/197   train_loss = 3.759
# Epoch  51 Batch  153/197   train_loss = 3.814
# Epoch  51 Batch  163/197   train_loss = 3.735
# Epoch  51 Batch  173/197   train_loss = 3.667
# Epoch  51 Batch  183/197   train_loss = 3.588
# Epoch  51 Batch  193/197   train_loss = 3.630
# Epoch  52 Batch    6/197   train_loss = 3.683
# Epoch  52 Batch   16/197   train_loss = 3.611
# Epoch  52 Batch   26/197   train_loss = 3.649
# Epoch  52 Batch   36/197   train_loss = 3.764
# Epoch  52 Batch   46/197   train_loss = 3.779
# Epoch  52 Batch   56/197   train_loss = 3.659
# Epoch  52 Batch   66/197   train_loss = 3.661
# Epoch  52 Batch   76/197   train_loss = 3.805
# Epoch  52 Batch   86/197   train_loss = 3.680
# Epoch  52 Batch   96/197   train_loss = 3.761
# Epoch  52 Batch  106/197   train_loss = 3.756
# Epoch  52 Batch  116/197   train_loss = 3.782
# Epoch  52 Batch  126/197   train_loss = 3.720
# Epoch  52 Batch  136/197   train_loss = 3.783
# Epoch  52 Batch  146/197   train_loss = 3.739
# Epoch  52 Batch  156/197   train_loss = 3.734
# Epoch  52 Batch  166/197   train_loss = 3.712
# Epoch  52 Batch  176/197   train_loss = 3.691
# ...
# Epoch  82 Batch   76/197   train_loss = 3.760
# Epoch  82 Batch   86/197   train_loss = 3.614
# Epoch  82 Batch   96/197   train_loss = 3.703
# Epoch  82 Batch  106/197   train_loss = 3.652
# Epoch  82 Batch  116/197   train_loss = 3.703
# Epoch  82 Batch  126/197   train_loss = 3.642
# Epoch  82 Batch  136/197   train_loss = 3.674
# Epoch  82 Batch  146/197   train_loss = 3.669
# Epoch  82 Batch  156/197   train_loss = 3.709
# Epoch  82 Batch  166/197   train_loss = 3.683
# Epoch  82 Batch  176/197   train_loss = 3.647
# Epoch  82 Batch  186/197   train_loss = 3.671
# Epoch  82 Batch  196/197   train_loss = 3.719
# Epoch  83 Batch    9/197   train_loss = 3.620
# Epoch  83 Batch   19/197   train_loss = 3.638
# Epoch  83 Batch   29/197   train_loss = 3.663
# Epoch  83 Batch   39/197   train_loss = 3.658
# Epoch  83 Batch   49/197   train_loss = 3.628
# Epoch  83 Batch   59/197   train_loss = 3.708
# Epoch  83 Batch   69/197   train_loss = 3.678
# Epoch  83 Batch   79/197   train_loss = 3.584
# Epoch  83 Batch   89/197   train_loss = 3.638
# Epoch  83 Batch   99/197   train_loss = 3.686
# Epoch  83 Batch  109/197   train_loss = 3.684
# Epoch  83 Batch  119/197   train_loss = 3.550
# Epoch  83 Batch  129/197   train_loss = 3.624
# Epoch  83 Batch  139/197   train_loss = 3.619
# Epoch  83 Batch  149/197   train_loss = 3.619
# Epoch  83 Batch  159/197   train_loss = 3.529
# Epoch  83 Batch  169/197   train_loss = 3.568
# Epoch  83 Batch  179/197   train_loss = 3.640
# Epoch  83 Batch  189/197   train_loss = 3.551
# Epoch  84 Batch    2/197   train_loss = 3.650
# Epoch  84 Batch   12/197   train_loss = 3.644
# Epoch  84 Batch   22/197   train_loss = 3.637
# Epoch  84 Batch   32/197   train_loss = 3.584
# Epoch  84 Batch   42/197   train_loss = 3.643
# Epoch  84 Batch   52/197   train_loss = 3.605
# Epoch  84 Batch   62/197   train_loss = 3.669
# Epoch  84 Batch   72/197   train_loss = 3.652
# Epoch  84 Batch   82/197   train_loss = 3.701
# Epoch  84 Batch   92/197   train_loss = 3.621
# Epoch  84 Batch  102/197   train_loss = 3.643
# Epoch  84 Batch  112/197   train_loss = 3.556
# Epoch  84 Batch  122/197   train_loss = 3.594
# Epoch  84 Batch  132/197   train_loss = 3.710
# Epoch  84 Batch  142/197   train_loss = 3.637
# Epoch  84 Batch  152/197   train_loss = 3.601
# Epoch  84 Batch  162/197   train_loss = 3.703
# Epoch  84 Batch  172/197   train_loss = 3.769
# Epoch  84 Batch  182/197   train_loss = 3.616
# Epoch  84 Batch  192/197   train_loss = 3.688
# Epoch  85 Batch    5/197   train_loss = 3.654
# Epoch  85 Batch   15/197   train_loss = 3.660
# Epoch  85 Batch   25/197   train_loss = 3.645
# Epoch  85 Batch   35/197   train_loss = 3.649
# Epoch  85 Batch   45/197   train_loss = 3.571
# Epoch  85 Batch   55/197   train_loss = 3.654
# Epoch  85 Batch   65/197   train_loss = 3.678
# Epoch  85 Batch   75/197   train_loss = 3.650
# Epoch  85 Batch   85/197   train_loss = 3.593
# Epoch  85 Batch   95/197   train_loss = 3.624
# Epoch  85 Batch  105/197   train_loss = 3.646
# Epoch  85 Batch  115/197   train_loss = 3.679
# Epoch  85 Batch  125/197   train_loss = 3.740
# Epoch  85 Batch  135/197   train_loss = 3.708
# Epoch  85 Batch  145/197   train_loss = 3.705
# Epoch  85 Batch  155/197   train_loss = 3.730
# Epoch  85 Batch  165/197   train_loss = 3.741
# Epoch  85 Batch  175/197   train_loss = 3.585
# Epoch  85 Batch  185/197   train_loss = 3.700
# Epoch  85 Batch  195/197   train_loss = 3.662
# Epoch  86 Batch    8/197   train_loss = 3.688
# Epoch  86 Batch   18/197   train_loss = 3.680
# Epoch  86 Batch   28/197   train_loss = 3.573
# Epoch  86 Batch   38/197   train_loss = 3.634
# Epoch  86 Batch   48/197   train_loss = 3.676
# Epoch  86 Batch   58/197   train_loss = 3.559
# Epoch  86 Batch   68/197   train_loss = 3.612
# Epoch  86 Batch   78/197   train_loss = 3.631
# Epoch  86 Batch   88/197   train_loss = 3.563
# Epoch  86 Batch   98/197   train_loss = 3.515
# Epoch  86 Batch  108/197   train_loss = 3.723
# Epoch  86 Batch  118/197   train_loss = 3.643
# Epoch  86 Batch  128/197   train_loss = 3.596
# Epoch  86 Batch  138/197   train_loss = 3.723
# Epoch  86 Batch  148/197   train_loss = 3.523
# Epoch  86 Batch  158/197   train_loss = 3.700
# Epoch  86 Batch  168/197   train_loss = 3.617
# Epoch  86 Batch  178/197   train_loss = 3.559
# Epoch  86 Batch  188/197   train_loss = 3.654
# Epoch  87 Batch    1/197   train_loss = 3.590
# Epoch  87 Batch   11/197   train_loss = 3.557
# Epoch  87 Batch   21/197   train_loss = 3.618
# Epoch  87 Batch   31/197   train_loss = 3.700
# Epoch  87 Batch   41/197   train_loss = 3.453
# Epoch  87 Batch   51/197   train_loss = 3.628
# Epoch  87 Batch   61/197   train_loss = 3.661
# Epoch  87 Batch   71/197   train_loss = 3.621
# Epoch  87 Batch   81/197   train_loss = 3.618
# Epoch  87 Batch   91/197   train_loss = 3.620
# Epoch  87 Batch  101/197   train_loss = 3.526
# Epoch  87 Batch  111/197   train_loss = 3.614
# Epoch  87 Batch  121/197   train_loss = 3.592
# Epoch  87 Batch  131/197   train_loss = 3.615
# Epoch  87 Batch  141/197   train_loss = 3.535
# Epoch  87 Batch  151/197   train_loss = 3.615
# Epoch  87 Batch  161/197   train_loss = 3.660
# Epoch  87 Batch  171/197   train_loss = 3.556
# Epoch  87 Batch  181/197   train_loss = 3.637
# Epoch  87 Batch  191/197   train_loss = 3.560
# Epoch  88 Batch    4/197   train_loss = 3.666
# Epoch  88 Batch   14/197   train_loss = 3.631
# Epoch  88 Batch   24/197   train_loss = 3.568
# Epoch  88 Batch   34/197   train_loss = 3.573
# Epoch  88 Batch   44/197   train_loss = 3.767
# Epoch  88 Batch   54/197   train_loss = 3.630
# Epoch  88 Batch   64/197   train_loss = 3.651
# Epoch  88 Batch   74/197   train_loss = 3.614
# Epoch  88 Batch   84/197   train_loss = 3.633
# Epoch  88 Batch   94/197   train_loss = 3.673
# Epoch  88 Batch  104/197   train_loss = 3.572
# Epoch  88 Batch  114/197   train_loss = 3.663
# Epoch  88 Batch  124/197   train_loss = 3.618
# Epoch  88 Batch  134/197   train_loss = 3.650
# Epoch  88 Batch  144/197   train_loss = 3.631
# Epoch  88 Batch  154/197   train_loss = 3.604
# Epoch  88 Batch  164/197   train_loss = 3.775
# Epoch  88 Batch  174/197   train_loss = 3.673
# Epoch  88 Batch  184/197   train_loss = 3.622
# Epoch  88 Batch  194/197   train_loss = 3.725
# Epoch  89 Batch    7/197   train_loss = 3.589
# Epoch  89 Batch   17/197   train_loss = 3.651
# Epoch  89 Batch   27/197   train_loss = 3.688
# Epoch  89 Batch   37/197   train_loss = 3.647
# Epoch  89 Batch   47/197   train_loss = 3.568
# Epoch  89 Batch   57/197   train_loss = 3.659
# Epoch  89 Batch   67/197   train_loss = 3.728
# Epoch  89 Batch   77/197   train_loss = 3.667
# Epoch  89 Batch   87/197   train_loss = 3.522
# Epoch  89 Batch   97/197   train_loss = 3.664
# Epoch  89 Batch  107/197   train_loss = 3.579
# Epoch  89 Batch  117/197   train_loss = 3.601
# Epoch  89 Batch  127/197   train_loss = 3.681
# Epoch  89 Batch  137/197   train_loss = 3.563
# Epoch  89 Batch  147/197   train_loss = 3.682
# Epoch  89 Batch  157/197   train_loss = 3.538
# Epoch  89 Batch  167/197   train_loss = 3.668
# Epoch  89 Batch  177/197   train_loss = 3.642
# Epoch  89 Batch  187/197   train_loss = 3.590
# Epoch  90 Batch    0/197   train_loss = 3.615
# Epoch  90 Batch   10/197   train_loss = 3.676
# Epoch  90 Batch   20/197   train_loss = 3.567
# Epoch  90 Batch   30/197   train_loss = 3.706
# Epoch  90 Batch   40/197   train_loss = 3.714
# Epoch  90 Batch   50/197   train_loss = 3.722
# Epoch  90 Batch   60/197   train_loss = 3.601
# Epoch  90 Batch   70/197   train_loss = 3.673
# Epoch  90 Batch   80/197   train_loss = 3.745
# Epoch  90 Batch   90/197   train_loss = 3.614
# Epoch  90 Batch  100/197   train_loss = 3.649
# Epoch  90 Batch  110/197   train_loss = 3.650
# Epoch  90 Batch  120/197   train_loss = 3.559
# Epoch  90 Batch  130/197   train_loss = 3.644
# Epoch  90 Batch  140/197   train_loss = 3.620
# Epoch  90 Batch  150/197   train_loss = 3.590
# Epoch  90 Batch  160/197   train_loss = 3.684
# Epoch  90 Batch  170/197   train_loss = 3.578
# Epoch  90 Batch  180/197   train_loss = 3.587
# Epoch  90 Batch  190/197   train_loss = 3.628
# Epoch  91 Batch    3/197   train_loss = 3.743
# Epoch  91 Batch   13/197   train_loss = 3.667
# Epoch  91 Batch   23/197   train_loss = 3.619
# Epoch  91 Batch   33/197   train_loss = 3.607
# Epoch  91 Batch   43/197   train_loss = 3.692
# Epoch  91 Batch   53/197   train_loss = 3.650
# Epoch  91 Batch   63/197   train_loss = 3.645
# Epoch  91 Batch   73/197   train_loss = 3.638
# Epoch  91 Batch   83/197   train_loss = 3.609
# Epoch  91 Batch   93/197   train_loss = 3.633
# Epoch  91 Batch  103/197   train_loss = 3.540
# Epoch  91 Batch  113/197   train_loss = 3.631
# Epoch  91 Batch  123/197   train_loss = 3.722
# Epoch  91 Batch  133/197   train_loss = 3.563
# Epoch  91 Batch  143/197   train_loss = 3.725
# Epoch  91 Batch  153/197   train_loss = 3.684
# Epoch  91 Batch  163/197   train_loss = 3.690
# Epoch  91 Batch  173/197   train_loss = 3.551
# Epoch  91 Batch  183/197   train_loss = 3.540
# Epoch  91 Batch  193/197   train_loss = 3.555
# Epoch  92 Batch    6/197   train_loss = 3.628
# Epoch  92 Batch   16/197   train_loss = 3.579
# Epoch  92 Batch   26/197   train_loss = 3.634
# Epoch  92 Batch   36/197   train_loss = 3.648
# Epoch  92 Batch   46/197   train_loss = 3.643
# Epoch  92 Batch   56/197   train_loss = 3.561
# Epoch  92 Batch   66/197   train_loss = 3.548
# Epoch  92 Batch   76/197   train_loss = 3.707
# Epoch  92 Batch   86/197   train_loss = 3.582
# Epoch  92 Batch   96/197   train_loss = 3.655
# Epoch  92 Batch  106/197   train_loss = 3.643
# Epoch  92 Batch  116/197   train_loss = 3.709
# Epoch  92 Batch  126/197   train_loss = 3.627
# Epoch  92 Batch  136/197   train_loss = 3.672
# Epoch  92 Batch  146/197   train_loss = 3.624
# Epoch  92 Batch  156/197   train_loss = 3.702
# Epoch  92 Batch  166/197   train_loss = 3.661
# Epoch  92 Batch  176/197   train_loss = 3.638
# Epoch  92 Batch  186/197   train_loss = 3.668
# Epoch  92 Batch  196/197   train_loss = 3.652
# Epoch  93 Batch    9/197   train_loss = 3.568
# Epoch  93 Batch   19/197   train_loss = 3.598
# Epoch  93 Batch   29/197   train_loss = 3.631
# Epoch  93 Batch   39/197   train_loss = 3.680
# Epoch  93 Batch   49/197   train_loss = 3.653
# Epoch  93 Batch   59/197   train_loss = 3.689
# Epoch  93 Batch   69/197   train_loss = 3.665
# Epoch  93 Batch   79/197   train_loss = 3.555
# Epoch  93 Batch   89/197   train_loss = 3.586
# Epoch  93 Batch   99/197   train_loss = 3.617
# Epoch  93 Batch  109/197   train_loss = 3.699
# Epoch  93 Batch  119/197   train_loss = 3.535
# Epoch  93 Batch  129/197   train_loss = 3.622
# Epoch  93 Batch  139/197   train_loss = 3.583
# Epoch  93 Batch  149/197   train_loss = 3.609
# Epoch  93 Batch  159/197   train_loss = 3.532
# Epoch  93 Batch  169/197   train_loss = 3.537
# Epoch  93 Batch  179/197   train_loss = 3.585
# Epoch  93 Batch  189/197   train_loss = 3.538
# Epoch  94 Batch    2/197   train_loss = 3.630
# Epoch  94 Batch   12/197   train_loss = 3.584
# Epoch  94 Batch   22/197   train_loss = 3.599
# Epoch  94 Batch   32/197   train_loss = 3.522
# Epoch  94 Batch   42/197   train_loss = 3.643
# Epoch  94 Batch   52/197   train_loss = 3.593
# Epoch  94 Batch   62/197   train_loss = 3.640
# Epoch  94 Batch   72/197   train_loss = 3.642
# Epoch  94 Batch   82/197   train_loss = 3.666
# Epoch  94 Batch   92/197   train_loss = 3.598
# Epoch  94 Batch  102/197   train_loss = 3.619
# Epoch  94 Batch  112/197   train_loss = 3.534
# Epoch  94 Batch  122/197   train_loss = 3.552
# Epoch  94 Batch  132/197   train_loss = 3.720
# Epoch  94 Batch  142/197   train_loss = 3.634
# Epoch  94 Batch  152/197   train_loss = 3.585
# Epoch  94 Batch  162/197   train_loss = 3.686
# Epoch  94 Batch  172/197   train_loss = 3.668
# Epoch  94 Batch  182/197   train_loss = 3.606
# Epoch  94 Batch  192/197   train_loss = 3.627
# Epoch  95 Batch    5/197   train_loss = 3.633
# Epoch  95 Batch   15/197   train_loss = 3.632
# Epoch  95 Batch   25/197   train_loss = 3.663
# Epoch  95 Batch   35/197   train_loss = 3.630
# Epoch  95 Batch   45/197   train_loss = 3.555
# Epoch  95 Batch   55/197   train_loss = 3.593
# Epoch  95 Batch   65/197   train_loss = 3.670
# Epoch  95 Batch   75/197   train_loss = 3.585
# Epoch  95 Batch   85/197   train_loss = 3.636
# Epoch  95 Batch   95/197   train_loss = 3.624
# Epoch  95 Batch  105/197   train_loss = 3.640
# Epoch  95 Batch  115/197   train_loss = 3.700
# Epoch  95 Batch  125/197   train_loss = 3.738
# Epoch  95 Batch  135/197   train_loss = 3.694
# Epoch  95 Batch  145/197   train_loss = 3.705
# Epoch  95 Batch  155/197   train_loss = 3.751
# Epoch  95 Batch  165/197   train_loss = 3.696
# Epoch  95 Batch  175/197   train_loss = 3.572
# Epoch  95 Batch  185/197   train_loss = 3.694
# Epoch  95 Batch  195/197   train_loss = 3.629
# Epoch  96 Batch    8/197   train_loss = 3.660
# Epoch  96 Batch   18/197   train_loss = 3.661
# Epoch  96 Batch   28/197   train_loss = 3.573
# Epoch  96 Batch   38/197   train_loss = 3.649
# Epoch  96 Batch   48/197   train_loss = 3.654
# Epoch  96 Batch   58/197   train_loss = 3.480
# Epoch  96 Batch   68/197   train_loss = 3.641
# Epoch  96 Batch   78/197   train_loss = 3.588
# Epoch  96 Batch   88/197   train_loss = 3.531
# Epoch  96 Batch   98/197   train_loss = 3.468
# Epoch  96 Batch  108/197   train_loss = 3.668
# Epoch  96 Batch  118/197   train_loss = 3.662
# Epoch  96 Batch  128/197   train_loss = 3.597
# Epoch  96 Batch  138/197   train_loss = 3.673
# Epoch  96 Batch  148/197   train_loss = 3.564
# Epoch  96 Batch  158/197   train_loss = 3.679
# Epoch  96 Batch  168/197   train_loss = 3.612
# Epoch  96 Batch  178/197   train_loss = 3.600
# Epoch  96 Batch  188/197   train_loss = 3.664
# Epoch  97 Batch    1/197   train_loss = 3.537
# Epoch  97 Batch   11/197   train_loss = 3.527
# Epoch  97 Batch   21/197   train_loss = 3.600
# Epoch  97 Batch   31/197   train_loss = 3.693
# Epoch  97 Batch   41/197   train_loss = 3.454
# Epoch  97 Batch   51/197   train_loss = 3.631
# Epoch  97 Batch   61/197   train_loss = 3.641
# Epoch  97 Batch   71/197   train_loss = 3.611
# Epoch  97 Batch   81/197   train_loss = 3.610
# Epoch  97 Batch   91/197   train_loss = 3.630
# Epoch  97 Batch  101/197   train_loss = 3.477
# Epoch  97 Batch  111/197   train_loss = 3.590
# Epoch  97 Batch  121/197   train_loss = 3.623
# Epoch  97 Batch  131/197   train_loss = 3.638
# Epoch  97 Batch  141/197   train_loss = 3.509
# Epoch  97 Batch  151/197   train_loss = 3.580
# Epoch  97 Batch  161/197   train_loss = 3.641
# Epoch  97 Batch  171/197   train_loss = 3.552
# Epoch  97 Batch  181/197   train_loss = 3.637
# Epoch  97 Batch  191/197   train_loss = 3.552
# Epoch  98 Batch    4/197   train_loss = 3.649
# Epoch  98 Batch   14/197   train_loss = 3.603
# Epoch  98 Batch   24/197   train_loss = 3.564
# Epoch  98 Batch   34/197   train_loss = 3.549
# Epoch  98 Batch   44/197   train_loss = 3.741
# Epoch  98 Batch   54/197   train_loss = 3.604
# Epoch  98 Batch   64/197   train_loss = 3.615
# Epoch  98 Batch   74/197   train_loss = 3.630
# Epoch  98 Batch   84/197   train_loss = 3.645
# Epoch  98 Batch   94/197   train_loss = 3.660
# Epoch  98 Batch  104/197   train_loss = 3.555
# Epoch  98 Batch  114/197   train_loss = 3.714
# Epoch  98 Batch  124/197   train_loss = 3.595
# Epoch  98 Batch  134/197   train_loss = 3.592
# Epoch  98 Batch  144/197   train_loss = 3.650
# Epoch  98 Batch  154/197   train_loss = 3.608
# Epoch  98 Batch  164/197   train_loss = 3.753
# Epoch  98 Batch  174/197   train_loss = 3.655
# Epoch  98 Batch  184/197   train_loss = 3.581
# Epoch  98 Batch  194/197   train_loss = 3.697
# Epoch  99 Batch    7/197   train_loss = 3.598
# Epoch  99 Batch   17/197   train_loss = 3.617
# Epoch  99 Batch   27/197   train_loss = 3.715
# Epoch  99 Batch   37/197   train_loss = 3.601
# Epoch  99 Batch   47/197   train_loss = 3.485
# Epoch  99 Batch   57/197   train_loss = 3.600
# Epoch  99 Batch   67/197   train_loss = 3.695
# Epoch  99 Batch   77/197   train_loss = 3.643
# Epoch  99 Batch   87/197   train_loss = 3.541
# Epoch  99 Batch   97/197   train_loss = 3.678
# Epoch  99 Batch  107/197   train_loss = 3.566
# Epoch  99 Batch  117/197   train_loss = 3.590
# Epoch  99 Batch  127/197   train_loss = 3.688
# Epoch  99 Batch  137/197   train_loss = 3.562
# Epoch  99 Batch  147/197   train_loss = 3.671
# Epoch  99 Batch  157/197   train_loss = 3.525
# Epoch  99 Batch  167/197   train_loss = 3.640
# Epoch  99 Batch  177/197   train_loss = 3.604
# Epoch  99 Batch  187/197   train_loss = 3.558
# Model Trained and Saved

# %% [markdown]
# ## Save Parameters
# Save `seq_length` and `save_dir` for generating a new TV script.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params((seq_length, save_dir))

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, vocab_to_int, int_to_vocab, token_dict = helper.load_preprocess()
seq_length, load_dir = helper.load_params()
print('Done')
# Out:
# Done

# %% [markdown]
# ## Implement Generate Functions
# ### Get Tensors
# Get tensors from `loaded_graph` using the function [`get_tensor_by_name()`](https://www.tensorflow.org/api_docs/python/tf/Graph#get_tensor_by_name).  Get the tensors using the following names:
# - "input:0"
# - "initial_state:0"
# - "final_state:0"
# - "probs:0"
#
# Return the tensors in the following tuple `(InputTensor, InitialStateTensor, FinalStateTensor, ProbsTensor)`

# %%
def get_tensors(loaded_graph):
    """
    Get input, initial state, final state, and probabilities tensor from <loaded_graph>
    :param loaded_graph: TensorFlow graph loaded from file
    :return: Tuple (InputTensor, InitialStateTensor, FinalStateTensor, ProbsTensor)
    """
    # TODO: Implement Function
    
    InputTensor = loaded_graph.get_tensor_by_name("input:0")
    InitialStateTensor = loaded_graph.get_tensor_by_name("initial_state:0")
    FinalStateTensor = loaded_graph.get_tensor_by_name("final_state:0")
    ProbsTensor = loaded_graph.get_tensor_by_name("probs:0")
    
    return InputTensor, InitialStateTensor, FinalStateTensor, ProbsTensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_get_tensors(get_tensors)
# Out:
# Tests Passed

# %% [markdown]
# ### Choose Word
# Implement the `pick_word()` function to select the next word using `probabilities`.

# %%
def pick_word(probabilities, int_to_vocab):
    """
    Pick the next word in the generated text
    :param probabilities: Probabilites of the next word
    :param int_to_vocab: Dictionary of word ids as the keys and words as the values
    :return: String of the predicted word
    """
    # TODO: Implement Function
    #one_hot_encoded = np.argmax(probabilities, axis=0)
    one_hot_encoded = np.random.choice(len(int_to_vocab),p=probabilities)
    next_word = int_to_vocab[one_hot_encoded]
    
    return next_word

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_pick_word(pick_word)

#probabilities = np.random.uniform(0,1,6779)
#pick_word(probabilities, int_to_vocab)
# Out:
# Tests Passed

# %% [markdown]
# ## Generate TV Script
# This will generate the TV script for you.  Set `gen_length` to the length of TV script you want to generate.

# %%
gen_length = 20 # length of a tweet
#prime_word = '@'
choice = np.random.choice(len(int_to_vocab))
prime_word = int_to_vocab[choice]
prime_word

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_dir + '.meta')
    loader.restore(sess, load_dir)

    # Get Tensors from loaded model
    input_text, initial_state, final_state, probs = get_tensors(loaded_graph)

    # Sentences generation setup
    gen_sentences = [prime_word ]# + ':']
    prev_state = sess.run(initial_state, {input_text: np.array([[1]])})

    # Generate sentences
    for n in range(gen_length):
        # Dynamic Input
        dyn_input = [[vocab_to_int[word] for word in gen_sentences[-seq_length:]]]
        dyn_seq_length = len(dyn_input[0])

        # Get Prediction
        probabilities, prev_state = sess.run(
            [probs, final_state],
            {input_text: dyn_input, initial_state: prev_state})
        
        pred_word = pick_word(probabilities[dyn_seq_length-1], int_to_vocab)

        gen_sentences.append(pred_word)
    
    # Remove tokens
    tv_script = ' '.join(gen_sentences)
    for key, token in token_dict.items():
        ending = ' ' if key in ['\n', '(', '"'] else ''
        tv_script = tv_script.replace(' ' + token.lower(), key)
    tv_script = tv_script.replace('\n ', '\n')
    tv_script = tv_script.replace('( ', '(')
        
    print(tv_script)
# Out:
# prediction: lightweight @agschneiderman is terrible, gave a horrible contribution down a1a to the u. s. that the best
